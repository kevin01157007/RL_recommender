# %% [markdown]
# # **Movie Recommendation with LightGCN✨**
#
#
# This notebook walks you through building a movie recommendation system using LightGCN. You can read more about Graph Neural Networks (GNNs), LightGCN and movie recommendation in [this Medium tutorial](https://medium.com/@quinn.wang/eb6d112f1e8).
#
# By Qinchen Wang, Xiaoli Yang, Feiyang (Kathy) Yu as part of the Stanford [CS224W: Machine Learning with Graphs](http://web.stanford.edu/class/cs224w/) course project.
#
# Without further ado, let's get started!

# %% [markdown]
# # Setup
#
# We recommend using a hardware accelerator for the notebook. You can set a GPU via "Runtime" --> "Change runtime type".

# %%
# !pip install tensorly
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install torch-spline-conv -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install torch-geometric

# %%
import collections
import math
import os
import os.path as osp
from tqdm import tqdm
from typing import List
import random
import time
import zipfile

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.options.display.max_rows = 10
from sklearn import metrics
from tensorly import decomposition

import torch
from torch.functional import tensordot
from torch import nn, optim, Tensor
import torch_geometric
from torch_geometric.data import Dataset, Data, download_url, extract_zip
from torch_geometric.nn import MessagePassing
from torch_geometric.typing import Adj
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import os
#       4 import os.path as osp
# ----> 5 from tqdm import tqdm
#       6 from typing import List
#       7 import random
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
print(f"PyTorch has version {torch.__version__}")
print(f"Torch version: {torch.__version__}")
print(f"Cuda available: {torch.cuda.is_available()}")
print(f"Torch geometric version: {torch_geometric.__version__}")
# Out:
# PyTorch has version 2.6.0+cu118
# Torch version: 2.6.0+cu118
# Cuda available: True
# Torch geometric version: 2.6.1

# %% [markdown]
# # Configurations
#
# Configure the model and training process. These parameters will make more sense as you move along.

# %%
rating_threshold = 3  #@param {type: "integer"}: Ratings equal to or greater than 3 are positive items.

config_dict = {
    "num_samples_per_user": 100,
    "num_users": 500,

    "epochs": 10,
    "batch_size": 128,
    "lr": 0.001,
    "weight_decay": 0.1,

    "embedding_size": 64,
    "num_layers": 5,
    "K": 10,
    "mf_rank": 8,

    "minibatch_per_print": 10,
    "epochs_per_print": 1,

    "val_frac": 0.2,
    "test_frac": 0.1,

    "model_name": "model.pth"
}

# %% [markdown]
# # Dataset
#
# A great publicly available dataset for training movie recommenders is the MovieLens 1M dataset. The MovieLens 1M dataset consists of 1 million movie ratings of score 1 to 5, from 6000 users and 4000 movies.

# %%
DATA_PATH = "https://files.grouplens.org/datasets/movielens/ml-1m.zip"

# %%
def trans_ml(dat, thres):
    """
    Transform function that assign non-negative entries >= thres 1, and non-
    negative entries <= thres 0. Keep other entries the same.
    """
    thres = thres[0]
    matrix = dat['edge_index']
    matrix[(matrix < thres) & (matrix > -1)] = 0
    matrix[(matrix >= thres)] = 1
    dat['edge_index'] = matrix
    return dat


class MovieLens(Dataset):
    def __init__(self, root, transform=None, pre_transform=None,
            transform_args=None, pre_transform_args=None):
        """
        root = where the dataset should be stored. This folder is split
        into raw_dir (downloaded dataset) and processed_dir (process data).
        """
        super(MovieLens, self).__init__(root, transform, pre_transform)
        self.transform = transform
        self.pre_transform = pre_transform
        self.transform_args = transform_args
        self.pre_transform_args = pre_transform_args

    @property
    def raw_file_names(self):
        return "ml-1m.zip"

    @property
    def processed_file_names(self):
        return ["data_movielens.pt"]

    def download(self):
        # Download to `self.raw_dir`.
        download_url(DATA_PATH, self.raw_dir)

    def _load(self):
        print(self.raw_dir)
        # extract_zip(self.raw_paths[0], self.raw_dir)
        with zipfile.ZipFile(self.raw_paths[0], 'r') as zip_ref:
            zip_ref.extractall(self.raw_dir)
        unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
        users = pd.read_table(self.raw_dir+'/ml-1m/users.dat',
                              sep='::', header=None, names=unames,
                              engine='python', encoding='latin-1')
        rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
        ratings = pd.read_table(self.raw_dir+'/ml-1m/ratings.dat', sep='::',
                                header=None, names=rnames, engine='python',
                                encoding='latin-1')
        mnames = ['movie_id', 'title', 'genres']
        movies = pd.read_table(self.raw_dir+'/ml-1m/movies.dat', sep='::',
                               header=None, names=mnames, engine='python',
                               encoding='latin-1')
        dat = pd.merge(pd.merge(ratings, users), movies)

        return users, ratings, movies, dat

    def process(self):
        print('run process')
        # load information from file
        users, ratings, movies, dat = self._load()

        users = users['user_id']
        movies = movies['movie_id']

        num_users = config_dict["num_users"]
        if num_users != -1:
            users = users[:num_users]

        user_ids = range(len(users))
        movie_ids = range(len(movies))

        user_to_id = dict(zip(users, user_ids))
        movie_to_id = dict(zip(movies, movie_ids))

        # get adjacency info
        self.num_user = users.shape[0]
        self.num_item = movies.shape[0]

        # initialize the adjacency matrix
        rat = torch.zeros(self.num_user, self.num_item)

        for index, row in ratings.iterrows():
            user, movie, rating = row[:3]
            if num_users != -1:
                if user not in user_to_id: break
            # create ratings matrix where (i, j) entry represents the ratings
            # of movie j given by user i.
            rat[user_to_id[user], movie_to_id[movie]] = rating

        # create Data object
        data = Data(edge_index = rat,
                    raw_edge_index = rat.clone(),
                    data = ratings,
                    users = users,
                    items = movies)

        # apply any pre-transformation
        if self.pre_transform is not None:
            data = self.pre_transform(data, self.pre_transform_args)

        # apply any post_transformation
        # if self.transform is not None:
        #     # data = self.transform(data, self.transform_args)
        data = self.transform(data, [rating_threshold])

        # save the processed data into .pt file
        torch.save(data, osp.join(self.processed_dir, f'data_movielens.pt'))
        print('process finished')

    def len(self):
        """
        return the number of examples in your graph
        """
        # TODO: how to define number of examples
        return

    def get(self):
        """
        The logic to load a single graph
        """
        data = torch.load(osp.join(self.processed_dir, 'data_movielens.pt'), weights_only=False)
        return data

    def train_val_test_split(self, val_frac=0.2, test_frac=0.1):
        """
        Return two mask matrices (M, N) that represents edges present in the
        train and validation set
        """
        try:
            self.num_user, self.num_item
        except AttributeError:
            data = self.get()
            self.num_user = len(data["users"].unique())
            self.num_item = len(data["items"].unique())
        # get number of edges masked for training and validation
        num_train_replaced = \
            round((test_frac+val_frac)*self.num_user*self.num_item)
        num_val_show = round(val_frac*self.num_user*self.num_item)

        # edges masked during training
        indices_user = np.random.randint(0, self.num_user, num_train_replaced)
        indices_item = np.random.randint(0, self.num_item, num_train_replaced)

        # sample part of edges from training stage to be unmasked during
        # validation
        indices_val_user = np.random.choice(indices_user, num_val_show)
        indices_val_item = np.random.choice(indices_item, num_val_show)

        train_mask = torch.ones(self.num_user, self.num_item)
        train_mask[indices_user, indices_item] = 0

        val_mask = train_mask.clone()
        val_mask[indices_val_user, indices_val_item] = 1

        test_mask = torch.ones_like(train_mask)

        return train_mask, val_mask, test_mask

# %% [markdown]
# # LightGCN implementation
#
# Now let's dive into the model!

# %% [markdown]
# ## LightGCN neiborhood aggregation layer
#
# Starting with the initial embeddings $E^{(0)}$ and the bipartite graph, we iterate over each node to perform neighborhood aggregation. Note that LightGCN uses **a simple weighted sum aggregator** and **avoids the heavy-lifting feature transformation and nonlinear activation**.
#
# Within each layer, for each user in the graph, we compute its updated embedding as the weighted sum of embeddings from all its neighboring items (movies) following the formula below:
# $$ \textbf{e}_u^{(k+1)} = \sum_{i \in N_u} \frac{1}{\sqrt{|N_u|} \sqrt{|N_i|}} \textbf{e}_i^{(k)} $$
# where $ \textbf{e}_u^{(k)} $ and $ \textbf{e}_i^{(k)} $ are the user and item (movie) node embeddings at the k-th layer. $ |N_u| $ and $ |N_i| $ are the user and item nodes’ number of neighbors.
#
# Similarly, for each item, the updated embedding is computed using weighted sum of its neighboring users:
# $$ \textbf{e}_i^{(k+1)} = \sum_{i \in N_i} \frac{1}{\sqrt{|N_i|} \sqrt{|N_u|}} \textbf{e}_u^{(k)} $$

# %%
class LightGCNConv(MessagePassing):
    r"""The neighbor aggregation operator from the `"LightGCN: Simplifying and
    Powering Graph Convolution Network for Recommendation"
    <https://arxiv.org/abs/2002.02126#>`_ paper

    Args:
        in_channels (int): Size of each input sample, or :obj:`-1` to derive
            the size from the first input(s) to the forward method.
        out_channels (int): Size of each output sample.
        num_users (int): Number of users for recommendation.
        num_items (int): Number of items to recommend.
        **kwargs (optional): Additional arguments of
            :class:`torch_geometric.nn.conv.MessagePassing`.
    """
    def __init__(self, in_channels: int, out_channels: int,
                 num_users: int, num_items: int, **kwargs):
        super(LightGCNConv, self).__init__(**kwargs)

        self.in_channels = in_channels
        self.out_channels = out_channels

        self.num_users = num_users
        self.num_items = num_items

        self.reset_parameters()

    def reset_parameters(self):
        pass  # There are no layer parameters to learn.

    def forward(self, x: Tensor, edge_index: Adj) -> Tensor:
        """Performs neighborhood aggregation for user/item embeddings."""
        user_item = \
                torch.zeros(self.num_users, self.num_items, device=x.device)
        user_item[edge_index[:, 0], edge_index[:, 1]] = 1
        user_neighbor_counts = torch.sum(user_item, axis=1)
        item_neightbor_counts = torch.sum(user_item, axis=0)
        # Compute weight for aggregation: 1 / sqrt(N_u * N_i)
        weights = user_item / torch.sqrt(
                user_neighbor_counts.repeat(self.num_items, 1).T \
                * item_neightbor_counts.repeat(self.num_users, 1))
        weights = torch.nan_to_num(weights, nan=0)
        out = torch.concat((weights.T @ x[:self.num_users],
                            weights @ x[self.num_users:]), 0)
        return out

    def __repr__(self):
        return '{}({}, {})'.format(self.__class__.__name__, self.in_channels,
                                   self.out_channels)

# %% [markdown]
# ## LightGCN model
#
# At layer combination, instead of taking the embedding of the final layer, LightGCN computes **a weighted sum of the embeddings at different layers**:
# $$ \textbf{e}_u = \sum_{k=0}^K \alpha_k \textbf{e}_u^{(k)} $$
# $$ \textbf{e}_i = \sum_{k=0}^K \alpha_k \textbf{e}_i^{(k)} $$
# with $ \alpha \ge 0 $. Here, alpha values can either be learned as network parameters, or set as empirical hyperparameters. It has been found that $ \alpha = \frac{1}{K + 1} $ works well.
#
# LightGCN predicts based on the inner product of the final user and item (movie) embeddings:
# $$ \hat{y}_{ui} = \textbf{e}_u^T \textbf{e}_i $$
# This inner product measures the similarity between the user and movie, therefore allowing us to understand how likely it is for the user to like the movie.

# %%
class LightGCN(nn.Module):
    def __init__(self,
                 config: dict,
                 device=None,
                 **kwargs):
        super().__init__()

        self.num_users  = config["n_users"]
        self.num_items  = config["m_items"]
        self.embedding_size = config["embedding_size"]
        self.in_channels = self.embedding_size
        self.out_channels = self.embedding_size
        self.num_layers = config["num_layers"]

        # 0-th layer embedding.
        self.embedding_user_item = torch.nn.Embedding(
            num_embeddings=self.num_users + self.num_items,
            embedding_dim=self.embedding_size)
        self.alpha = None

        # random normal init seems to be a better choice when lightGCN actually
        # don't use any non-linear activation function
        nn.init.normal_(self.embedding_user_item.weight, mean=1.5, std=0.1)  # 均值为 1.5，标准差为 0.1
        print('use NORMAL distribution initilizer')

        self.f = nn.Sigmoid()

        self.convs = nn.ModuleList()
        self.convs.append(LightGCNConv(
                self.embedding_size, self.embedding_size,
                num_users=self.num_users, num_items=self.num_items, **kwargs))

        for _ in range(1, self.num_layers):
            self.convs.append(
                LightGCNConv(
                        self.embedding_size, self.embedding_size,
                        num_users=self.num_users, num_items=self.num_items,
                        **kwargs))

        self.device = None
        if device is not None:
            self.convs.to(device)
            self.device = device

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()

    def forward(self, x: Tensor, edge_index: Adj, *args, **kwargs) -> Tensor:
        xs: List[Tensor] = []

        edge_index = torch.nonzero(edge_index)
        for i in range(self.num_layers):
            x = self.convs[i](x, edge_index, *args, **kwargs)
            if self.device is not None:
                x = x.to(self.device)
            xs.append(x)
        xs = torch.stack(xs)

        self.alpha = 1 / (1 + self.num_layers) * torch.ones(xs.shape)
        if self.device is not None:
            self.alpha = self.alpha.to(self.device)
            xs = xs.to(self.device)
        x = (xs * self.alpha).sum(dim=0)  # Sum along K layers.
        return x

    def __repr__(self) -> str:
        return (f'{self.__class__.__name__}({self.in_channels}, '
                f'{self.out_channels}, num_layers={self.num_layers})')

# %% [markdown]
# ## Utility functions
#
# The utility functions allow us to retrieve embeddings and compute user-item similarities. These will become userful later on.

# %%
def getUsersRating(model, users, data):
    """ Get the embedding of users
    INPUT:
        model: the LightGCN model you are training on
        users: this is the user index (note: use 0-indexed and not user number,
            which is 1-indexed)
        data: the entire data, used to fetch all users and all items
    """
    all_users_items = model(model.embedding_user_item.weight.clone(),
                            data["edge_index"])
    all_users = all_users_items[:len(data["users"])]
    items_emb = all_users_items[len(data["users"]):]
    users_emb = all_users[users.long()]
    rating = model.f(torch.matmul(users_emb, items_emb.t()))
    return rating

def getEmbedding(model, users, pos, neg, data, mask):
    """
    INPUT:
        model: the LightGCN model you are training on
        users: this is the user index (note: use 0-indexed and not user number,
            which is 1-indexed)
        pos: positive index corresponding to an item that the user like
        neg: negative index corresponding to an item that the user doesn't like
        data: the entire data, used to fetch all users and all items
        mask: Masking matrix indicating edges present in the current
            train / validation / test set.
    """
    # assuming we always search for users and items by their indices (instead of
    # user/item number)
    all_users_items = model(model.embedding_user_item.weight.clone(),
                            data["edge_index"] * mask)
    all_users = all_users_items[:len(data["users"])]
    all_items = all_users_items[len(data["users"]):]
    users_emb = all_users[users]
    pos_emb = all_items[pos]
    neg_emb = all_items[neg]
    n_user = len(data["users"])
    users_emb_ego = model.embedding_user_item(users)
    # offset the index to fetch embedding from user_item
    pos_emb_ego = model.embedding_user_item(pos + n_user)
    neg_emb_ego = model.embedding_user_item(neg + n_user)
    return users_emb, pos_emb, neg_emb, users_emb_ego, pos_emb_ego, neg_emb_ego

# %% [markdown]
# ## Bayesian Personalized Ranking loss (BPR loss)
#
# To train the LightGCN model, we need an objective function that aligns with our goal for movie recommendation. We use the Bayesian Personalized Ranking (BPR) loss, which encourages observed user-item predictions to have increasingly higher values than unobserved ones, along with $ L_2 $ regularization:
# $$ L_{BPR} = - \sum_{u=1}^M \sum_{i \in N_u} \sum_{j \notin N_u} \ln \sigma(\hat{y}_{ui} - \hat{y}_{uj}) + \lambda ||\textbf{E}^{(0)} ||^2 $$
# where $ \textbf{E}^{(0)} $ is a matrix with column vectors being the 0-th layer embeddings to learn.

# %%
def bpr_loss(model, users, pos, neg, data, mask):
    """
    INPUT:
        model: the LightGCN model you are training on
        users: this is the user index (note: use 0-indexed and not user number,
            which is 1-indexed)
        pos: positive index corresponding to an item that the user like
            (0-indexed, note to index items starting from 0)
        neg: negative index corresponding to an item that the user doesn't like
        data: the entire data, used to fetch all users and all items
        mask: Masking matrix indicating edges present in the current
            train / validation / test set.
    OUTPUT:
        loss, reg_loss
    """
    # assuming we always sample the same number of positive and negative sample
    # per user
    assert len(users) == len(pos) and len(users) == len(neg)
    (users_emb, pos_emb, neg_emb,
    userEmb0,  posEmb0, negEmb0) = getEmbedding(model, users.long(), pos.long(),
                                                neg.long(), data, mask)
    reg_loss = (1/2)*(userEmb0.norm(2).pow(2) +
                        posEmb0.norm(2).pow(2)  +
                        negEmb0.norm(2).pow(2))/float(len(users))
    pos_scores = torch.mul(users_emb, pos_emb)
    pos_scores = torch.sum(pos_scores, dim=1)
    neg_scores = torch.mul(users_emb, neg_emb)
    neg_scores = torch.sum(neg_scores, dim=1)

    loss = torch.mean(torch.nn.functional.softplus(neg_scores - pos_scores))

    return loss, reg_loss

# %% [markdown]
# ## Personalized top K precision and recall
#
# To evaluate training progress and model performance, we compute the **top K precision and recall** scores. Specifically, for each user, we rank movie items in order of decreasing similarity and choose the best K to recommend. Then, we compute the precision and recall of those K recommendations against ground truth items that the user likes and dislikes.

# %%
def personalized_topk(pred, K, user_indices, edge_index):
    """Computes TopK precision and recall.

    Args:
        pred: Predicted similarities between user and item.
        K: Number of items to rank.
        user_indices: Indices of users for each prediction in `pred`.
        edge_index: User and item connection matrix.

    Returns:
        Average Top K precision and recall for users in `user_indices`.
    """
    per_user_preds = collections.defaultdict(list)
    for index, user in enumerate(user_indices):
        per_user_preds[user.item()].append(pred[index].item())
    precisions = 0.0
    recalls = 0.0
    for user, preds in per_user_preds.items():
        while len(preds) < K:
            preds.append(random.choice(range(edge_index.shape[1])))
        top_ratings, top_items = torch.topk(torch.tensor(preds), K)
        correct_preds = edge_index[user, top_items].sum().item()
        total_pos = edge_index[user].sum().item()
        precisions += correct_preds / K
        recalls += correct_preds / total_pos if total_pos != 0 else 0
    num_users = len(user_indices.unique())
    return precisions / num_users, recalls / num_users

# %% [markdown]
# # Training, validation and testing
#
# Now, let's train our LightGCN model, and run it on the validation and test sets.

# %% [markdown]
# ## Sampling
#
# For each user, we randomly sample $n$ positive-negative movie examples and add them to the training, validation or test set. $n$ is a parameter that we can specify and tune.

# %%
def _sample_pos_neg(data, mask, num_samples_per_user):
    """Samples (user, positive item, negative item) tuples per user.

    If a user does not have a postive (negative) item, we choose an item
    with unknown liking (an item without raw rating data).

    Args:
        data: Dataset object containing edge_index and raw ratings matrix.
        mask: Masking matrix indicating edges present in the current
            train / validation / test set.
        num_samples_per_user: Number of samples to generate for each user.

    Returns:
        torch.Tensor object of (user, positive item, negative item) samples.
    """
    print("=====Starting to sample=====")
    start = time.time()
    samples = []
    all_items = set(range(len(data["items"])))
    for user_index, user in enumerate(data["users"]):
        pos_items = set(
            torch.nonzero(data["edge_index"][user_index])[:, 0].tolist())
        unknown_items = all_items.difference(
                set(
                    torch.nonzero(
                        data["raw_edge_index"][user_index])[:, 0].tolist()))
        neg_items = all_items.difference(
            set(pos_items)).difference(set(unknown_items))
        unmasked_items = set(torch.nonzero(mask[user_index])[:, 0].tolist())
        if len(unknown_items.union(pos_items)) == 0 or \
                len(unknown_items.union(neg_items)) == 0:
            continue
        for _ in range(num_samples_per_user):
            if len(pos_items.intersection(unmasked_items)) == 0:
                pos_item_index = random.choice(
                    list(unknown_items.intersection(unmasked_items)))
            else:
                pos_item_index = random.choice(
                    list(pos_items.intersection(unmasked_items)))
            if len(neg_items.intersection(unmasked_items)) == 0:
                neg_item_index = random.choice(
                    list(unknown_items.intersection(unmasked_items)))
            else:
                neg_item_index = random.choice(
                    list(neg_items.intersection(unmasked_items)))
            samples.append((user_index, pos_item_index, neg_item_index))
    end = time.time()
    print(f"=====Sampling completed (took {end - start} seconds)=====")
    return torch.tensor(samples, dtype=torch.int32)

def sample_pos_neg(data, train_mask, val_mask, test_mask, num_samples_per_user):
    """Samples (user, positive item, negative item) tuples per user.

    If a user does not have a postive (negative) item, we choose an item
    with unknown liking (an item without raw rating data).

    Args:
        data: Dataset object containing edge_index and raw ratings matrix.
        train_mask: Masking matrix indicating edges present in train set.
        val_mask: Masking matrix indicating edges present in validation set.
        test_mask: Masking matrix indicating edges present in test set.
        num_samples_per_user: Number of samples to generate for each user.

    Returns:
        torch.Tensor object of (user, positive item, negative item) samples for
        train, validation and test.
    """
    train_samples = _sample_pos_neg(data, train_mask, num_samples_per_user)
    val_samples = _sample_pos_neg(data, val_mask, num_samples_per_user)
    test_samples = _sample_pos_neg(data, test_mask, num_samples_per_user)
    return train_samples, val_samples, test_samples

# %% [markdown]
# ## Training and validation
#
# Now, let's start training!

# %%
root = os.getcwd()
movielens = MovieLens(root=root, transform=trans_ml)
data = movielens.get()
train_mask, val_mask, test_mask = \
        movielens.train_val_test_split(val_frac=config_dict["val_frac"],
                                       test_frac=config_dict["test_frac"])

n_users = len(data["users"].unique())
m_items = len(data["items"].unique())
print(f"#Users: {n_users}")
print(f"#Items: {m_items}")

model_config = {
    "n_users": n_users,
    "m_items": m_items,
    "embedding_size": config_dict["embedding_size"],
    "num_layers": config_dict["num_layers"],
}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
lightGCN = LightGCN(model_config, device=device)

num_samples_per_user = config_dict["num_samples_per_user"]
epochs = config_dict["epochs"]
batch_size = config_dict["batch_size"]
lr = config_dict["lr"]
weight_decay = config_dict["weight_decay"]

K = config_dict["K"]

lightGCN.to(device)

samples_train, samples_val, samples_test = \
        sample_pos_neg(data, train_mask, val_mask, test_mask,
                       num_samples_per_user)

samples_train=samples_train.to(device)
samples_val=samples_val.to(device)
samples_test=samples_test.to(device)
train_mask=train_mask.to(device)
val_mask=val_mask.to(device)
test_mask=test_mask.to(device)
data = data.to(device)

print(f"#Training samples: {len(samples_train)}",
      f"#Validation samples: {len(samples_val)}",
      f"#Test samples: {len(samples_test)}")

optimizer = optim.Adam(lightGCN.parameters(), lr=lr)
print("Optimizer:", optimizer)

epochs_tracked = []
train_topks = []
val_topks = []

for epoch in range(epochs):
    print("Training on the {} epoch".format(epoch))
    lightGCN.train()
    loss_sum = 0
    # Shuffle the order of rows.
    samples_train = samples_train[torch.randperm(samples_train.size()[0])]
    for batch_idx in range(math.ceil(len(samples_train) / batch_size)):
        optimizer.zero_grad()

        current_batch = \
            samples_train[batch_idx*batch_size: (batch_idx+1)*batch_size]
        # Shuffle the order of rows.
        current_batch = current_batch[torch.randperm(current_batch.size()[0])]
        users = current_batch[:, 0:1]
        pos = current_batch[:, 1:2]
        neg = current_batch[:, 2:3]

        loss, reg_loss = bpr_loss(lightGCN, users, pos, neg, data,
                                  train_mask)
        reg_loss = reg_loss * weight_decay
        loss = loss + reg_loss
        loss_sum += loss.detach()

        loss.backward()
        optimizer.step()

        if batch_idx % config_dict["minibatch_per_print"] == 0:
            all_users = torch.linspace(start=0,
                                       end=n_users - 1, steps=n_users).long()
            user_indices = current_batch[:, 0]
            user_indices = user_indices.repeat(2).long() #對應pos、neg
            item_indices = torch.cat(
                (current_batch[:, 1], current_batch[:, 2])).long()
            pred = getUsersRating(lightGCN,
                                  all_users,
                                  data)[user_indices, item_indices]
            truth = data["edge_index"][user_indices, item_indices]
            topk_precision, topk_recall = \
                personalized_topk(pred, K, user_indices, data["edge_index"])

            print("Training on epoch {} minibatch {}/{} completed\n".format(epoch, batch_idx+1,
                                                                            math.ceil(len(samples_train) / batch_size)),
                  "bpr_loss on current minibatch is {}, and regularization loss is {}.\n".format(round(float(loss.detach().cpu()), 6),
                                                                                                 round(float(reg_loss.detach().cpu()), 6)),
                  "Top K precision = {}, recall = {}.".format(topk_precision, topk_recall))

    if epoch % config_dict["epochs_per_print"] == 0:
        epochs_tracked.append(epoch)

        # evaluation on both the trainisng and validation set
        lightGCN.eval()
        # predict on the training set
        users = samples_train[:, 0:1]
        user_indices = samples_train[:, 0]
        user_indices = user_indices.repeat(2).long()
        item_indices = torch.cat(
            (samples_train[:, 1], samples_train[:, 2])).long()
        pred = getUsersRating(lightGCN,
                              users[:,0],
                              data)[user_indices, item_indices]
        truth = data["edge_index"][users.long()[:,0]]\
            [user_indices, item_indices]
        train_topk_precision, train_topk_recall = \
            personalized_topk(pred, K, user_indices, data["edge_index"])
        train_topks.append((train_topk_precision, train_topk_recall))

        # predict on the validation set
        users_val = samples_val[:, 0:1]
        pos_val = samples_val[:, 1:2]
        neg_val = samples_val[:, 2:3]

        loss_val, reg_loss_val = bpr_loss(
            lightGCN, users_val, pos_val, neg_val, data, val_mask)
        reg_loss_val = reg_loss_val * weight_decay

        # predict on the validation set
        user_indices = samples_val[:, 0]
        user_indices = user_indices.repeat(2).long()
        item_indices = torch.cat((samples_val[:, 1], samples_val[:, 2])).long()
        pred_val = getUsersRating(lightGCN,
                                  users_val[:,0],
                                  data)[user_indices, item_indices]
        truth_val = data["edge_index"][users_val.long()[:,0]]\
            [user_indices, item_indices]
        val_topk_precision, val_topk_recall = \
            personalized_topk(pred_val, K, user_indices, data["edge_index"])
        val_topks.append((val_topk_precision, val_topk_recall))

        print("\nTraining on {} epoch completed.\n".format(epoch),
              "Average bpr_loss on train set is {} for the current epoch.\n".format(round(float(loss_sum/len(samples_train)), 6)),
              "Training top K precision = {}, recall = {}.\n".format(train_topk_precision, train_topk_recall),
              "Average bpr_loss on the validation set is {}, and regularization loss is {}.\n".format(round(float((loss_val+reg_loss_val)/len(samples_val)), 6),
                                                                                                      round(float(reg_loss_val/len(samples_val)), 6)),
              "Validation top K precision = {}, recall = {}.\n".format(val_topk_precision, val_topk_recall))
# Out:
# run process
# c:\Users\k0920\Documents\GitHub\RL_recommender\raw
# Processing...
# process finished
# #Users: 500
# #Items: 3883
# use NORMAL distribution initilizer
# =====Starting to sample=====
# Done!
# =====Sampling completed (took 0.848747968673706 seconds)=====
# =====Starting to sample=====
# =====Sampling completed (took 0.8342053890228271 seconds)=====
# =====Starting to sample=====
# =====Sampling completed (took 0.8315715789794922 seconds)=====
# #Training samples: 50000 #Validation samples: 50000 #Test samples: 50000
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# Training on the 0 epoch
# Training on epoch 0 minibatch 1/391 completed
#  bpr_loss on current minibatch is 22.367893, and regularization loss is 21.674498.
#  Top K precision = 0.09576271186440673, recall = 0.006615839763127295.
# Training on epoch 0 minibatch 11/391 completed
#  bpr_loss on current minibatch is 22.278389, and regularization loss is 21.584852.
#  Top K precision = 0.09304347826086948, recall = 0.006939939555062189.
# Training on epoch 0 minibatch 21/391 completed
#  bpr_loss on current minibatch is 22.179201, and regularization loss is 21.489777.
#  Top K precision = 0.09115044247787607, recall = 0.00720619649092873.
# Training on epoch 0 minibatch 31/391 completed
#  bpr_loss on current minibatch is 22.107313, and regularization loss is 21.414093.
#  Top K precision = 0.08303571428571423, recall = 0.006209418717217336.
# Training on epoch 0 minibatch 41/391 completed
#  bpr_loss on current minibatch is 21.950937, and regularization loss is 21.257324.
#  Top K precision = 0.08141592920353982, recall = 0.007418784830877685.
# Training on epoch 0 minibatch 51/391 completed
#  bpr_loss on current minibatch is 21.826841, and regularization loss is 21.132208.
#  Top K precision = 0.08571428571428565, recall = 0.006939920887909449.
# Training on epoch 0 minibatch 61/391 completed
#  bpr_loss on current minibatch is 21.672325, and regularization loss is 20.980179.
#  Top K precision = 0.08290598290598288, recall = 0.007809912095291318.
# Training on epoch 0 minibatch 71/391 completed
#  bpr_loss on current minibatch is 21.60779, and regularization loss is 20.914228.
#  Top K precision = 0.1078260869565217, recall = 0.006396197177425988.
# Training on epoch 0 minibatch 81/391 completed
#  bpr_loss on current minibatch is 21.444944, and regularization loss is 20.752014.
#  Top K precision = 0.08181818181818179, recall = 0.0068587215057406845.
# Training on epoch 0 minibatch 91/391 completed
#  bpr_loss on current minibatch is 21.345947, and regularization loss is 20.653107.
#  Top K precision = 0.0936363636363636, recall = 0.00695455841845738.
# Training on epoch 0 minibatch 101/391 completed
#  bpr_loss on current minibatch is 21.240038, and regularization loss is 20.547443.
#  Top K precision = 0.0843478260869565, recall = 0.006078125082198233.
# Training on epoch 0 minibatch 111/391 completed
#  bpr_loss on current minibatch is 21.077135, and regularization loss is 20.38291.
#  Top K precision = 0.08333333333333329, recall = 0.0069025806337061416.
# Training on epoch 0 minibatch 121/391 completed
#  bpr_loss on current minibatch is 21.034348, and regularization loss is 20.340717.
#  Top K precision = 0.08991596638655457, recall = 0.008127010555953112.
# Training on epoch 0 minibatch 131/391 completed
#  bpr_loss on current minibatch is 20.865051, and regularization loss is 20.168097.
#  Top K precision = 0.09203539823008845, recall = 0.007402985323607762.
# Training on epoch 0 minibatch 141/391 completed
#  bpr_loss on current minibatch is 20.743645, and regularization loss is 20.047871.
#  Top K precision = 0.0991228070175438, recall = 0.007648172639200904.
# Training on epoch 0 minibatch 151/391 completed
#  bpr_loss on current minibatch is 20.607615, and regularization loss is 19.914804.
#  Top K precision = 0.06491228070175437, recall = 0.006373989442237401.
# Training on epoch 0 minibatch 161/391 completed
#  bpr_loss on current minibatch is 20.550526, and regularization loss is 19.856878.
#  Top K precision = 0.09823008849557519, recall = 0.007956203498427773.
# Training on epoch 0 minibatch 171/391 completed
#  bpr_loss on current minibatch is 20.40345, and regularization loss is 19.711197.
#  Top K precision = 0.07826086956521736, recall = 0.0065861472069656014.
# Training on epoch 0 minibatch 181/391 completed
#  bpr_loss on current minibatch is 20.292017, and regularization loss is 19.598944.
#  Top K precision = 0.07857142857142853, recall = 0.006223637750236849.
# Training on epoch 0 minibatch 191/391 completed
#  bpr_loss on current minibatch is 20.160988, and regularization loss is 19.468195.
#  Top K precision = 0.0848214285714285, recall = 0.0074036771797069715.
# Training on epoch 0 minibatch 201/391 completed
#  bpr_loss on current minibatch is 20.017561, and regularization loss is 19.325052.
#  Top K precision = 0.08461538461538454, recall = 0.007353704694656127.
# Training on epoch 0 minibatch 211/391 completed
#  bpr_loss on current minibatch is 19.966131, and regularization loss is 19.273392.
#  Top K precision = 0.09649122807017539, recall = 0.005818581332790889.
# Training on epoch 0 minibatch 221/391 completed
#  bpr_loss on current minibatch is 19.866236, and regularization loss is 19.172302.
#  Top K precision = 0.06697247706422019, recall = 0.005426272119126809.
# Training on epoch 0 minibatch 231/391 completed
#  bpr_loss on current minibatch is 19.885555, and regularization loss is 19.192169.
#  Top K precision = 0.08749999999999993, recall = 0.006279537467338322.
# Training on epoch 0 minibatch 241/391 completed
#  bpr_loss on current minibatch is 19.638594, and regularization loss is 18.94643.
#  Top K precision = 0.07232142857142855, recall = 0.005945824386998627.
# Training on epoch 0 minibatch 251/391 completed
#  bpr_loss on current minibatch is 19.519625, and regularization loss is 18.828644.
#  Top K precision = 0.0701754385964912, recall = 0.0068888926839586915.
# Training on epoch 0 minibatch 261/391 completed
#  bpr_loss on current minibatch is 19.460419, and regularization loss is 18.767567.
#  Top K precision = 0.06695652173913041, recall = 0.005615247925281581.
# Training on epoch 0 minibatch 271/391 completed
#  bpr_loss on current minibatch is 19.232321, and regularization loss is 18.540493.
#  Top K precision = 0.06846846846846844, recall = 0.007442625238715798.
# Training on epoch 0 minibatch 281/391 completed
#  bpr_loss on current minibatch is 19.32337, and regularization loss is 18.628881.
#  Top K precision = 0.09203539823008845, recall = 0.0069675240752431426.
# Training on epoch 0 minibatch 291/391 completed
#  bpr_loss on current minibatch is 19.019726, and regularization loss is 18.326893.
#  Top K precision = 0.06034482758620687, recall = 0.005524306621409023.
# Training on epoch 0 minibatch 301/391 completed
#  bpr_loss on current minibatch is 19.058733, and regularization loss is 18.365479.
#  Top K precision = 0.07280701754385963, recall = 0.007266454676173262.
# Training on epoch 0 minibatch 311/391 completed
#  bpr_loss on current minibatch is 18.818687, and regularization loss is 18.123386.
#  Top K precision = 0.09743589743589738, recall = 0.006732164010760117.
# Training on epoch 0 minibatch 321/391 completed
#  bpr_loss on current minibatch is 18.757027, and regularization loss is 18.063883.
#  Top K precision = 0.08421052631578943, recall = 0.007471332719961199.
# Training on epoch 0 minibatch 331/391 completed
#  bpr_loss on current minibatch is 18.640165, and regularization loss is 17.948675.
#  Top K precision = 0.08017241379310339, recall = 0.00722376067487506.
# Training on epoch 0 minibatch 341/391 completed
#  bpr_loss on current minibatch is 18.54995, and regularization loss is 17.858454.
#  Top K precision = 0.08230088495575219, recall = 0.007253199501056368.
# Training on epoch 0 minibatch 351/391 completed
#  bpr_loss on current minibatch is 18.418455, and regularization loss is 17.726185.
#  Top K precision = 0.07543859649122805, recall = 0.0062512014064124094.
# Training on epoch 0 minibatch 361/391 completed
#  bpr_loss on current minibatch is 18.202662, and regularization loss is 17.511211.
#  Top K precision = 0.08859649122807016, recall = 0.0073603404884097934.
# Training on epoch 0 minibatch 371/391 completed
#  bpr_loss on current minibatch is 18.285158, and regularization loss is 17.592779.
#  Top K precision = 0.09217391304347823, recall = 0.008789415670345205.
# Training on epoch 0 minibatch 381/391 completed
#  bpr_loss on current minibatch is 18.191935, and regularization loss is 17.497765.
#  Top K precision = 0.09326923076923076, recall = 0.006578376290520786.
# Training on epoch 0 minibatch 391/391 completed
#  bpr_loss on current minibatch is 18.186825, and regularization loss is 17.489592.
#  Top K precision = 0.0780821917808219, recall = 0.005923023153087246.
#
# Training on 0 epoch completed.
#  Average bpr_loss on train set is 0.157741 for the current epoch.
#  Training top K precision = 0.042400000000000014, recall = 0.0036209001226759695.
#  Average bpr_loss on the validation set is 0.000361, and regularization loss is 0.000347.
#  Validation top K precision = 0.03299999999999995, recall = 0.0024841071189593243.
#
# Training on the 1 epoch
# Training on epoch 1 minibatch 1/391 completed
#  bpr_loss on current minibatch is 18.113297, and regularization loss is 17.419529.
#  Top K precision = 0.08017241379310343, recall = 0.005822989766987818.
# Training on epoch 1 minibatch 11/391 completed
#  bpr_loss on current minibatch is 17.958788, and regularization loss is 17.265289.
#  Top K precision = 0.0821428571428571, recall = 0.0076693528279377044.
# Training on epoch 1 minibatch 21/391 completed
#  bpr_loss on current minibatch is 17.826025, and regularization loss is 17.134771.
#  Top K precision = 0.0961538461538461, recall = 0.006700603838744652.
# Training on epoch 1 minibatch 31/391 completed
#  bpr_loss on current minibatch is 17.826294, and regularization loss is 17.132318.
#  Top K precision = 0.07499999999999998, recall = 0.006069696835824331.
# Training on epoch 1 minibatch 41/391 completed
#  bpr_loss on current minibatch is 17.687038, and regularization loss is 16.993475.
#  Top K precision = 0.07478260869565216, recall = 0.0053990273091095355.
# Training on epoch 1 minibatch 51/391 completed
#  bpr_loss on current minibatch is 17.41098, and regularization loss is 16.714838.
#  Top K precision = 0.07946428571428567, recall = 0.006570546248893266.
# Training on epoch 1 minibatch 61/391 completed
#  bpr_loss on current minibatch is 17.388048, and regularization loss is 16.696516.
#  Top K precision = 0.08938053097345125, recall = 0.0077954574587618545.
# Training on epoch 1 minibatch 71/391 completed
#  bpr_loss on current minibatch is 17.359606, and regularization loss is 16.666155.
#  Top K precision = 0.08813559322033894, recall = 0.005471366155407991.
# Training on epoch 1 minibatch 81/391 completed
#  bpr_loss on current minibatch is 17.232378, and regularization loss is 16.541662.
#  Top K precision = 0.07999999999999997, recall = 0.005570482980076481.
# Training on epoch 1 minibatch 91/391 completed
#  bpr_loss on current minibatch is 17.221329, and regularization loss is 16.527407.
#  Top K precision = 0.07636363636363633, recall = 0.006109320527342138.
# Training on epoch 1 minibatch 101/391 completed
#  bpr_loss on current minibatch is 16.992477, and regularization loss is 16.300362.
#  Top K precision = 0.08468468468468465, recall = 0.007987047070807688.
# Training on epoch 1 minibatch 111/391 completed
#  bpr_loss on current minibatch is 17.028502, and regularization loss is 16.334099.
#  Top K precision = 0.09166666666666662, recall = 0.007484840189828721.
# Training on epoch 1 minibatch 121/391 completed
#  bpr_loss on current minibatch is 16.799553, and regularization loss is 16.10812.
#  Top K precision = 0.10446428571428566, recall = 0.007670901558893467.
# Training on epoch 1 minibatch 131/391 completed
#  bpr_loss on current minibatch is 16.815985, and regularization loss is 16.123152.
#  Top K precision = 0.08761061946902653, recall = 0.006187188214390157.
# Training on epoch 1 minibatch 141/391 completed
#  bpr_loss on current minibatch is 16.53837, and regularization loss is 15.845654.
#  Top K precision = 0.08571428571428565, recall = 0.005641060565476474.
# Training on epoch 1 minibatch 151/391 completed
#  bpr_loss on current minibatch is 16.669357, and regularization loss is 15.976392.
#  Top K precision = 0.081578947368421, recall = 0.007098216319743887.
# Training on epoch 1 minibatch 161/391 completed
#  bpr_loss on current minibatch is 16.438349, and regularization loss is 15.745067.
#  Top K precision = 0.09217391304347824, recall = 0.007307095801146057.
# Training on epoch 1 minibatch 171/391 completed
#  bpr_loss on current minibatch is 16.095179, and regularization loss is 15.402643.
#  Top K precision = 0.10086206896551717, recall = 0.00736999575137705.
# Training on epoch 1 minibatch 181/391 completed
#  bpr_loss on current minibatch is 16.135277, and regularization loss is 15.442351.
#  Top K precision = 0.08189655172413789, recall = 0.00736867227135315.
# Training on epoch 1 minibatch 191/391 completed
#  bpr_loss on current minibatch is 16.379236, and regularization loss is 15.686034.
#  Top K precision = 0.08173913043478258, recall = 0.007263085695034096.
# Training on epoch 1 minibatch 201/391 completed
#  bpr_loss on current minibatch is 15.919174, and regularization loss is 15.225636.
#  Top K precision = 0.07857142857142853, recall = 0.007073179286252858.
# Training on epoch 1 minibatch 211/391 completed
#  bpr_loss on current minibatch is 15.770616, and regularization loss is 15.077675.
#  Top K precision = 0.08288288288288283, recall = 0.005915122715416402.
# Training on epoch 1 minibatch 221/391 completed
#  bpr_loss on current minibatch is 15.796218, and regularization loss is 15.103249.
#  Top K precision = 0.10782608695652168, recall = 0.007906736492005849.
# Training on epoch 1 minibatch 231/391 completed
#  bpr_loss on current minibatch is 15.822634, and regularization loss is 15.127666.
#  Top K precision = 0.0859649122807017, recall = 0.008236574703466332.
# Training on epoch 1 minibatch 241/391 completed
#  bpr_loss on current minibatch is 15.630675, and regularization loss is 14.937241.
#  Top K precision = 0.09487179487179484, recall = 0.00683470376257693.
# Training on epoch 1 minibatch 251/391 completed
#  bpr_loss on current minibatch is 15.851656, and regularization loss is 15.158258.
#  Top K precision = 0.08347826086956515, recall = 0.0056941478739315635.
# Training on epoch 1 minibatch 261/391 completed
#  bpr_loss on current minibatch is 15.629246, and regularization loss is 14.935205.
#  Top K precision = 0.09741379310344822, recall = 0.00709663807759912.
# Training on epoch 1 minibatch 271/391 completed
#  bpr_loss on current minibatch is 15.730837, and regularization loss is 15.038548.
#  Top K precision = 0.08828828828828825, recall = 0.006425064655484655.
# Training on epoch 1 minibatch 281/391 completed
#  bpr_loss on current minibatch is 15.513923, and regularization loss is 14.821774.
#  Top K precision = 0.07522123893805306, recall = 0.004754514244573446.
# Training on epoch 1 minibatch 291/391 completed
#  bpr_loss on current minibatch is 15.326626, and regularization loss is 14.633097.
#  Top K precision = 0.0911504424778761, recall = 0.006162218824751751.
# Training on epoch 1 minibatch 301/391 completed
#  bpr_loss on current minibatch is 15.214999, and regularization loss is 14.520927.
#  Top K precision = 0.07964601769911499, recall = 0.005905412545028268.
# Training on epoch 1 minibatch 311/391 completed
#  bpr_loss on current minibatch is 15.089574, and regularization loss is 14.397388.
#  Top K precision = 0.09238095238095233, recall = 0.007652610119059055.
# Training on epoch 1 minibatch 321/391 completed
#  bpr_loss on current minibatch is 15.037772, and regularization loss is 14.344935.
#  Top K precision = 0.09652173913043473, recall = 0.009161530913008316.
# Training on epoch 1 minibatch 331/391 completed
#  bpr_loss on current minibatch is 14.739877, and regularization loss is 14.047399.
#  Top K precision = 0.07203389830508472, recall = 0.0062408069520686355.
# Training on epoch 1 minibatch 341/391 completed
#  bpr_loss on current minibatch is 14.762543, and regularization loss is 14.069211.
#  Top K precision = 0.07837837837837833, recall = 0.006391576055303978.
# Training on epoch 1 minibatch 351/391 completed
#  bpr_loss on current minibatch is 14.745035, and regularization loss is 14.05195.
#  Top K precision = 0.08859649122807008, recall = 0.007643299411482381.
# Training on epoch 1 minibatch 361/391 completed
#  bpr_loss on current minibatch is 14.615356, and regularization loss is 13.921183.
#  Top K precision = 0.08545454545454541, recall = 0.006017072492499177.
# Training on epoch 1 minibatch 371/391 completed
#  bpr_loss on current minibatch is 14.77418, and regularization loss is 14.081451.
#  Top K precision = 0.07064220183486238, recall = 0.004532142613870775.
# Training on epoch 1 minibatch 381/391 completed
#  bpr_loss on current minibatch is 14.472921, and regularization loss is 13.775757.
#  Top K precision = 0.09166666666666666, recall = 0.0068996480366328205.
# Training on epoch 1 minibatch 391/391 completed
#  bpr_loss on current minibatch is 14.383366, and regularization loss is 13.690207.
#  Top K precision = 0.06575342465753424, recall = 0.006659908288425189.
#
# Training on 1 epoch completed.
#  Average bpr_loss on train set is 0.126478 for the current epoch.
#  Training top K precision = 0.047400000000000046, recall = 0.0039436557595094665.
#  Average bpr_loss on the validation set is 0.000289, and regularization loss is 0.000275.
#  Validation top K precision = 0.03319999999999995, recall = 0.0024932121224829325.
#
# Training on the 2 epoch
# Training on epoch 2 minibatch 1/391 completed
#  bpr_loss on current minibatch is 14.533288, and regularization loss is 13.840097.
#  Top K precision = 0.0788990825688073, recall = 0.007298350779877953.
# Training on epoch 2 minibatch 11/391 completed
#  bpr_loss on current minibatch is 14.318394, and regularization loss is 13.625882.
#  Top K precision = 0.10598290598290593, recall = 0.010256334322708695.
# Training on epoch 2 minibatch 21/391 completed
#  bpr_loss on current minibatch is 14.338118, and regularization loss is 13.645747.
#  Top K precision = 0.08571428571428567, recall = 0.008022461402848484.
# Training on epoch 2 minibatch 31/391 completed
#  bpr_loss on current minibatch is 14.096534, and regularization loss is 13.406035.
#  Top K precision = 0.08157894736842103, recall = 0.0068102380488748475.
# Training on epoch 2 minibatch 41/391 completed
#  bpr_loss on current minibatch is 14.027317, and regularization loss is 13.333852.
#  Top K precision = 0.08508771929824559, recall = 0.007632897011979962.
# Training on epoch 2 minibatch 51/391 completed
#  bpr_loss on current minibatch is 14.197222, and regularization loss is 13.503473.
#  Top K precision = 0.08660714285714281, recall = 0.007125807721696015.
# Training on epoch 2 minibatch 61/391 completed
#  bpr_loss on current minibatch is 14.134239, and regularization loss is 13.439307.
#  Top K precision = 0.0938053097345132, recall = 0.008644860048161913.
# Training on epoch 2 minibatch 71/391 completed
#  bpr_loss on current minibatch is 13.899102, and regularization loss is 13.207094.
#  Top K precision = 0.07927927927927923, recall = 0.0065441154762311115.
# Training on epoch 2 minibatch 81/391 completed
#  bpr_loss on current minibatch is 13.861692, and regularization loss is 13.168746.
#  Top K precision = 0.07413793103448274, recall = 0.0066940613910634935.
# Training on epoch 2 minibatch 91/391 completed
#  bpr_loss on current minibatch is 13.720676, and regularization loss is 13.026153.
#  Top K precision = 0.08918918918918918, recall = 0.005805011682998414.
# Training on epoch 2 minibatch 101/391 completed
#  bpr_loss on current minibatch is 13.640783, and regularization loss is 12.948636.
#  Top K precision = 0.09369369369369367, recall = 0.007181524468086485.
# Training on epoch 2 minibatch 111/391 completed
#  bpr_loss on current minibatch is 13.719582, and regularization loss is 13.026505.
#  Top K precision = 0.08362068965517237, recall = 0.006032861062730739.
# Training on epoch 2 minibatch 121/391 completed
#  bpr_loss on current minibatch is 13.429038, and regularization loss is 12.735237.
#  Top K precision = 0.0736363636363636, recall = 0.006815840189351254.
# Training on epoch 2 minibatch 131/391 completed
#  bpr_loss on current minibatch is 13.576498, and regularization loss is 12.885749.
#  Top K precision = 0.08849557522123891, recall = 0.0073459771138717185.
# Training on epoch 2 minibatch 141/391 completed
#  bpr_loss on current minibatch is 13.174946, and regularization loss is 12.482305.
#  Top K precision = 0.08425925925925923, recall = 0.006489187554819019.
# Training on epoch 2 minibatch 151/391 completed
#  bpr_loss on current minibatch is 13.128067, and regularization loss is 12.435373.
#  Top K precision = 0.07563025210084029, recall = 0.007642129249782237.
# Training on epoch 2 minibatch 161/391 completed
#  bpr_loss on current minibatch is 13.00639, and regularization loss is 12.313536.
#  Top K precision = 0.10619469026548667, recall = 0.007326471821686806.
# Training on epoch 2 minibatch 171/391 completed
#  bpr_loss on current minibatch is 13.155032, and regularization loss is 12.461084.
#  Top K precision = 0.07966101694915252, recall = 0.007439898180584295.
# Training on epoch 2 minibatch 181/391 completed
#  bpr_loss on current minibatch is 13.01411, and regularization loss is 12.321054.
#  Top K precision = 0.08230088495575219, recall = 0.006749633211304053.
# Training on epoch 2 minibatch 191/391 completed
#  bpr_loss on current minibatch is 12.802707, and regularization loss is 12.110501.
#  Top K precision = 0.07999999999999997, recall = 0.006971578744091195.
# Training on epoch 2 minibatch 201/391 completed
#  bpr_loss on current minibatch is 12.8072, and regularization loss is 12.115273.
#  Top K precision = 0.07368421052631578, recall = 0.007190375672446695.
# Training on epoch 2 minibatch 211/391 completed
#  bpr_loss on current minibatch is 12.603458, and regularization loss is 11.910121.
#  Top K precision = 0.09166666666666663, recall = 0.006302519596917607.
# Training on epoch 2 minibatch 221/391 completed
#  bpr_loss on current minibatch is 12.531931, and regularization loss is 11.839412.
#  Top K precision = 0.08165137614678897, recall = 0.007725564649567242.
# Training on epoch 2 minibatch 231/391 completed
#  bpr_loss on current minibatch is 12.76235, and regularization loss is 12.070868.
#  Top K precision = 0.0854545454545454, recall = 0.008844674655266671.
# Training on epoch 2 minibatch 241/391 completed
#  bpr_loss on current minibatch is 12.376031, and regularization loss is 11.683204.
#  Top K precision = 0.07980769230769226, recall = 0.007011988720432149.
# Training on epoch 2 minibatch 251/391 completed
#  bpr_loss on current minibatch is 12.420822, and regularization loss is 11.730047.
#  Top K precision = 0.08376068376068373, recall = 0.007008455752075979.
# Training on epoch 2 minibatch 261/391 completed
#  bpr_loss on current minibatch is 12.344173, and regularization loss is 11.650863.
#  Top K precision = 0.07522123893805306, recall = 0.005690395300013815.
# Training on epoch 2 minibatch 271/391 completed
#  bpr_loss on current minibatch is 12.071521, and regularization loss is 11.378582.
#  Top K precision = 0.08173913043478256, recall = 0.0077337749249061834.
# Training on epoch 2 minibatch 281/391 completed
#  bpr_loss on current minibatch is 12.155584, and regularization loss is 11.462839.
#  Top K precision = 0.09999999999999998, recall = 0.007100747035465881.
# Training on epoch 2 minibatch 291/391 completed
#  bpr_loss on current minibatch is 12.143698, and regularization loss is 11.45138.
#  Top K precision = 0.08839285714285706, recall = 0.007612544978026481.
# Training on epoch 2 minibatch 301/391 completed
#  bpr_loss on current minibatch is 12.182995, and regularization loss is 11.489026.
#  Top K precision = 0.07610619469026547, recall = 0.005962017324615652.
# Training on epoch 2 minibatch 311/391 completed
#  bpr_loss on current minibatch is 12.020953, and regularization loss is 11.327248.
#  Top K precision = 0.07678571428571425, recall = 0.006451098093017591.
# Training on epoch 2 minibatch 321/391 completed
#  bpr_loss on current minibatch is 12.028605, and regularization loss is 11.333643.
#  Top K precision = 0.09327731092436972, recall = 0.006744144640002571.
# Training on epoch 2 minibatch 331/391 completed
#  bpr_loss on current minibatch is 11.98171, and regularization loss is 11.28847.
#  Top K precision = 0.06475409836065571, recall = 0.005146959644057852.
# Training on epoch 2 minibatch 341/391 completed
#  bpr_loss on current minibatch is 11.782138, and regularization loss is 11.089151.
#  Top K precision = 0.06293103448275861, recall = 0.0058549012308159055.
# Training on epoch 2 minibatch 351/391 completed
#  bpr_loss on current minibatch is 11.400219, and regularization loss is 10.705632.
#  Top K precision = 0.06756756756756756, recall = 0.007041110563090387.
# Training on epoch 2 minibatch 361/391 completed
#  bpr_loss on current minibatch is 11.739776, and regularization loss is 11.045453.
#  Top K precision = 0.08660714285714281, recall = 0.007905447778400316.
# Training on epoch 2 minibatch 371/391 completed
#  bpr_loss on current minibatch is 11.701268, and regularization loss is 11.008461.
#  Top K precision = 0.09115044247787607, recall = 0.006574579097326699.
# Training on epoch 2 minibatch 381/391 completed
#  bpr_loss on current minibatch is 11.629834, and regularization loss is 10.935605.
#  Top K precision = 0.07913043478260866, recall = 0.005386021494499081.
# Training on epoch 2 minibatch 391/391 completed
#  bpr_loss on current minibatch is 11.376052, and regularization loss is 10.684312.
#  Top K precision = 0.07402597402597402, recall = 0.005945034440903092.
#
# Training on 2 epoch completed.
#  Average bpr_loss on train set is 0.1007 for the current epoch.
#  Training top K precision = 0.04000000000000001, recall = 0.002962628343809351.
#  Average bpr_loss on the validation set is 0.00023, and regularization loss is 0.000216.
#  Validation top K precision = 0.03259999999999994, recall = 0.00243500485922897.
#
# Training on the 3 epoch
# Training on epoch 3 minibatch 1/391 completed
#  bpr_loss on current minibatch is 11.485711, and regularization loss is 10.793145.
#  Top K precision = 0.0876106194690265, recall = 0.0067005789209005975.
# Training on epoch 3 minibatch 11/391 completed
#  bpr_loss on current minibatch is 11.464837, and regularization loss is 10.76994.
#  Top K precision = 0.07982456140350873, recall = 0.007267207108547098.
# Training on epoch 3 minibatch 21/391 completed
#  bpr_loss on current minibatch is 11.40657, and regularization loss is 10.713191.
#  Top K precision = 0.07090909090909091, recall = 0.007417980095190561.
# Training on epoch 3 minibatch 31/391 completed
#  bpr_loss on current minibatch is 11.184813, and regularization loss is 10.491126.
#  Top K precision = 0.08053097345132741, recall = 0.0077071082498223085.
# Training on epoch 3 minibatch 41/391 completed
#  bpr_loss on current minibatch is 11.23869, and regularization loss is 10.545644.
#  Top K precision = 0.0786324786324786, recall = 0.005834045862927801.
# Training on epoch 3 minibatch 51/391 completed
#  bpr_loss on current minibatch is 10.926991, and regularization loss is 10.234355.
#  Top K precision = 0.09736842105263156, recall = 0.007782527608752802.
# Training on epoch 3 minibatch 61/391 completed
#  bpr_loss on current minibatch is 10.950642, and regularization loss is 10.25907.
#  Top K precision = 0.07410714285714282, recall = 0.0063098503432402475.
# Training on epoch 3 minibatch 71/391 completed
#  bpr_loss on current minibatch is 11.161542, and regularization loss is 10.468721.
#  Top K precision = 0.07657657657657654, recall = 0.00723879283832746.
# Training on epoch 3 minibatch 81/391 completed
#  bpr_loss on current minibatch is 10.974693, and regularization loss is 10.281985.
#  Top K precision = 0.09369369369369364, recall = 0.0058446871627421985.
# Training on epoch 3 minibatch 91/391 completed
#  bpr_loss on current minibatch is 11.128035, and regularization loss is 10.433619.
#  Top K precision = 0.07863247863247858, recall = 0.0066214574487192335.
# Training on epoch 3 minibatch 101/391 completed
#  bpr_loss on current minibatch is 10.29547, and regularization loss is 9.601877.
#  Top K precision = 0.08584070796460172, recall = 0.006891895766767111.
# Training on epoch 3 minibatch 111/391 completed
#  bpr_loss on current minibatch is 10.657584, and regularization loss is 9.9659.
#  Top K precision = 0.09482758620689649, recall = 0.007800036183705979.
# Training on epoch 3 minibatch 121/391 completed
#  bpr_loss on current minibatch is 10.348888, and regularization loss is 9.656784.
#  Top K precision = 0.07982456140350874, recall = 0.006864614242761564.
# Training on epoch 3 minibatch 131/391 completed
#  bpr_loss on current minibatch is 10.431851, and regularization loss is 9.739699.
#  Top K precision = 0.0875, recall = 0.006830962121954774.
# Training on epoch 3 minibatch 141/391 completed
#  bpr_loss on current minibatch is 10.633172, and regularization loss is 9.939597.
#  Top K precision = 0.09999999999999994, recall = 0.008175995255055723.
# Training on epoch 3 minibatch 151/391 completed
#  bpr_loss on current minibatch is 10.41237, and regularization loss is 9.719241.
#  Top K precision = 0.0885964912280701, recall = 0.005642194085674077.
# Training on epoch 3 minibatch 161/391 completed
#  bpr_loss on current minibatch is 10.526815, and regularization loss is 9.834344.
#  Top K precision = 0.09292035398230081, recall = 0.005837381312200511.
# Training on epoch 3 minibatch 171/391 completed
#  bpr_loss on current minibatch is 10.409021, and regularization loss is 9.717498.
#  Top K precision = 0.0946428571428571, recall = 0.007007366612461477.
# Training on epoch 3 minibatch 181/391 completed
#  bpr_loss on current minibatch is 10.174354, and regularization loss is 9.480793.
#  Top K precision = 0.07321428571428569, recall = 0.006950241093516688.
# Training on epoch 3 minibatch 191/391 completed
#  bpr_loss on current minibatch is 10.231298, and regularization loss is 9.536852.
#  Top K precision = 0.087719298245614, recall = 0.0062393206169858466.
# Training on epoch 3 minibatch 201/391 completed
#  bpr_loss on current minibatch is 10.045917, and regularization loss is 9.353072.
#  Top K precision = 0.10964912280701747, recall = 0.008017071131730535.
# Training on epoch 3 minibatch 211/391 completed
#  bpr_loss on current minibatch is 9.975463, and regularization loss is 9.282438.
#  Top K precision = 0.08983050847457623, recall = 0.007745555479239473.
# Training on epoch 3 minibatch 221/391 completed
#  bpr_loss on current minibatch is 9.983496, and regularization loss is 9.290263.
#  Top K precision = 0.08666666666666661, recall = 0.0071415017604993785.
# Training on epoch 3 minibatch 231/391 completed
#  bpr_loss on current minibatch is 9.989048, and regularization loss is 9.295641.
#  Top K precision = 0.08534482758620686, recall = 0.008337976066680087.
# Training on epoch 3 minibatch 241/391 completed
#  bpr_loss on current minibatch is 10.103561, and regularization loss is 9.410927.
#  Top K precision = 0.09454545454545452, recall = 0.008228859790725239.
# Training on epoch 3 minibatch 251/391 completed
#  bpr_loss on current minibatch is 10.082171, and regularization loss is 9.388209.
#  Top K precision = 0.09051724137931032, recall = 0.005658892246748096.
# Training on epoch 3 minibatch 261/391 completed
#  bpr_loss on current minibatch is 9.933482, and regularization loss is 9.241515.
#  Top K precision = 0.0943396226415094, recall = 0.00819541629214481.
# Training on epoch 3 minibatch 271/391 completed
#  bpr_loss on current minibatch is 9.726235, and regularization loss is 9.032872.
#  Top K precision = 0.07196261682242988, recall = 0.004655934219411249.
# Training on epoch 3 minibatch 281/391 completed
#  bpr_loss on current minibatch is 9.896179, and regularization loss is 9.201726.
#  Top K precision = 0.08521739130434779, recall = 0.0059434934178982666.
# Training on epoch 3 minibatch 291/391 completed
#  bpr_loss on current minibatch is 9.619802, and regularization loss is 8.926578.
#  Top K precision = 0.07207207207207206, recall = 0.005932053185223103.
# Training on epoch 3 minibatch 301/391 completed
#  bpr_loss on current minibatch is 9.560143, and regularization loss is 8.866248.
#  Top K precision = 0.08165137614678897, recall = 0.006066399190473548.
# Training on epoch 3 minibatch 311/391 completed
#  bpr_loss on current minibatch is 9.627337, and regularization loss is 8.934984.
#  Top K precision = 0.08448275862068962, recall = 0.007685199838896935.
# Training on epoch 3 minibatch 321/391 completed
#  bpr_loss on current minibatch is 9.409206, and regularization loss is 8.716636.
#  Top K precision = 0.08596491228070172, recall = 0.006128529142206555.
# Training on epoch 3 minibatch 331/391 completed
#  bpr_loss on current minibatch is 9.171981, and regularization loss is 8.478324.
#  Top K precision = 0.0787610619469026, recall = 0.006816493499621163.
# Training on epoch 3 minibatch 341/391 completed
#  bpr_loss on current minibatch is 8.909199, and regularization loss is 8.216483.
#  Top K precision = 0.08050847457627115, recall = 0.006423722654351727.
# Training on epoch 3 minibatch 351/391 completed
#  bpr_loss on current minibatch is 9.570857, and regularization loss is 8.876987.
#  Top K precision = 0.09824561403508764, recall = 0.007507992440844672.
# Training on epoch 3 minibatch 361/391 completed
#  bpr_loss on current minibatch is 9.039447, and regularization loss is 8.34608.
#  Top K precision = 0.06886792452830186, recall = 0.005319280972204425.
# Training on epoch 3 minibatch 371/391 completed
#  bpr_loss on current minibatch is 9.039083, and regularization loss is 8.345625.
#  Top K precision = 0.09629629629629625, recall = 0.008387105108362313.
# Training on epoch 3 minibatch 381/391 completed
#  bpr_loss on current minibatch is 8.943048, and regularization loss is 8.249976.
#  Top K precision = 0.08782608695652168, recall = 0.007994907348872081.
# Training on epoch 3 minibatch 391/391 completed
#  bpr_loss on current minibatch is 8.818723, and regularization loss is 8.12593.
#  Top K precision = 0.0813333333333333, recall = 0.005694002069558897.
#
# Training on 3 epoch completed.
#  Average bpr_loss on train set is 0.079679 for the current epoch.
#  Training top K precision = 0.04340000000000005, recall = 0.003387522691458317.
#  Average bpr_loss on the validation set is 0.000182, and regularization loss is 0.000168.
#  Validation top K precision = 0.03239999999999994, recall = 0.00248768606400884.
#
# Training on the 4 epoch
# Training on epoch 4 minibatch 1/391 completed
#  bpr_loss on current minibatch is 9.275493, and regularization loss is 8.582235.
#  Top K precision = 0.07310924369747894, recall = 0.0052677598458601834.
# Training on epoch 4 minibatch 11/391 completed
#  bpr_loss on current minibatch is 8.74015, and regularization loss is 8.046052.
#  Top K precision = 0.08347826086956518, recall = 0.006526867938369755.
# Training on epoch 4 minibatch 21/391 completed
#  bpr_loss on current minibatch is 8.587936, and regularization loss is 7.894925.
#  Top K precision = 0.07454545454545451, recall = 0.006826263619864676.
# Training on epoch 4 minibatch 31/391 completed
#  bpr_loss on current minibatch is 8.793083, and regularization loss is 8.101086.
#  Top K precision = 0.0789473684210526, recall = 0.005726116883376392.
# Training on epoch 4 minibatch 41/391 completed
#  bpr_loss on current minibatch is 9.136255, and regularization loss is 8.442145.
#  Top K precision = 0.10360360360360354, recall = 0.00815934344809876.
# Training on epoch 4 minibatch 51/391 completed
#  bpr_loss on current minibatch is 8.862252, and regularization loss is 8.170307.
#  Top K precision = 0.09067796610169485, recall = 0.005861325483046667.
# Training on epoch 4 minibatch 61/391 completed
#  bpr_loss on current minibatch is 8.530276, and regularization loss is 7.837318.
#  Top K precision = 0.09642857142857142, recall = 0.006583164380827066.
# Training on epoch 4 minibatch 71/391 completed
#  bpr_loss on current minibatch is 8.897799, and regularization loss is 8.205394.
#  Top K precision = 0.08434782608695647, recall = 0.005760392244625173.
# Training on epoch 4 minibatch 81/391 completed
#  bpr_loss on current minibatch is 9.045469, and regularization loss is 8.352492.
#  Top K precision = 0.09743589743589738, recall = 0.007139991480971097.
# Training on epoch 4 minibatch 91/391 completed
#  bpr_loss on current minibatch is 8.304024, and regularization loss is 7.610818.
#  Top K precision = 0.07826086956521736, recall = 0.007787982896455489.
# Training on epoch 4 minibatch 101/391 completed
#  bpr_loss on current minibatch is 8.515461, and regularization loss is 7.822027.
#  Top K precision = 0.08909090909090905, recall = 0.007801124083393453.
# Training on epoch 4 minibatch 111/391 completed
#  bpr_loss on current minibatch is 8.57895, and regularization loss is 7.884978.
#  Top K precision = 0.0866071428571428, recall = 0.007209556502337603.
# Training on epoch 4 minibatch 121/391 completed
#  bpr_loss on current minibatch is 8.437423, and regularization loss is 7.74442.
#  Top K precision = 0.08018018018018014, recall = 0.0059743893293430494.
# Training on epoch 4 minibatch 131/391 completed
#  bpr_loss on current minibatch is 8.283205, and regularization loss is 7.590071.
#  Top K precision = 0.1046728971962616, recall = 0.008149011695878111.
# Training on epoch 4 minibatch 141/391 completed
#  bpr_loss on current minibatch is 8.281551, and regularization loss is 7.588538.
#  Top K precision = 0.08135593220338977, recall = 0.006654555492533945.
# Training on epoch 4 minibatch 151/391 completed
#  bpr_loss on current minibatch is 8.367374, and regularization loss is 7.674394.
#  Top K precision = 0.10185185185185174, recall = 0.008761776709284677.
# Training on epoch 4 minibatch 161/391 completed
#  bpr_loss on current minibatch is 8.360919, and regularization loss is 7.66814.
#  Top K precision = 0.0841666666666666, recall = 0.0073725706802302065.
# Training on epoch 4 minibatch 171/391 completed
#  bpr_loss on current minibatch is 8.032867, and regularization loss is 7.340522.
#  Top K precision = 0.09203539823008845, recall = 0.008338377504446791.
# Training on epoch 4 minibatch 181/391 completed
#  bpr_loss on current minibatch is 8.044769, and regularization loss is 7.352097.
#  Top K precision = 0.07454545454545451, recall = 0.008813992398177954.
# Training on epoch 4 minibatch 191/391 completed
#  bpr_loss on current minibatch is 8.117043, and regularization loss is 7.423709.
#  Top K precision = 0.08938053097345126, recall = 0.006161689694332375.
# Training on epoch 4 minibatch 201/391 completed
#  bpr_loss on current minibatch is 7.987783, and regularization loss is 7.296126.
#  Top K precision = 0.08899082568807339, recall = 0.0055718423593240475.
# Training on epoch 4 minibatch 211/391 completed
#  bpr_loss on current minibatch is 8.166302, and regularization loss is 7.474365.
#  Top K precision = 0.10088495575221233, recall = 0.007919668892680263.
# Training on epoch 4 minibatch 221/391 completed
#  bpr_loss on current minibatch is 7.903145, and regularization loss is 7.209779.
#  Top K precision = 0.08571428571428567, recall = 0.006273377328939011.
# Training on epoch 4 minibatch 231/391 completed
#  bpr_loss on current minibatch is 7.828905, and regularization loss is 7.135347.
#  Top K precision = 0.08990825688073388, recall = 0.006532328116626393.
# Training on epoch 4 minibatch 241/391 completed
#  bpr_loss on current minibatch is 7.67456, and regularization loss is 6.982262.
#  Top K precision = 0.07075471698113205, recall = 0.006855951245972795.
# Training on epoch 4 minibatch 251/391 completed
#  bpr_loss on current minibatch is 7.908806, and regularization loss is 7.215997.
#  Top K precision = 0.08971962616822426, recall = 0.0061955988546362655.
# Training on epoch 4 minibatch 261/391 completed
#  bpr_loss on current minibatch is 7.519847, and regularization loss is 6.827442.
#  Top K precision = 0.07913043478260866, recall = 0.007638693533952383.
# Training on epoch 4 minibatch 271/391 completed
#  bpr_loss on current minibatch is 7.748603, and regularization loss is 7.055571.
#  Top K precision = 0.08608695652173909, recall = 0.006634013134213044.
# Training on epoch 4 minibatch 281/391 completed
#  bpr_loss on current minibatch is 7.436458, and regularization loss is 6.742713.
#  Top K precision = 0.06296296296296293, recall = 0.005184515886270371.
# Training on epoch 4 minibatch 291/391 completed
#  bpr_loss on current minibatch is 7.480953, and regularization loss is 6.787863.
#  Top K precision = 0.08545454545454541, recall = 0.005944373942825325.
# Training on epoch 4 minibatch 301/391 completed
#  bpr_loss on current minibatch is 7.485349, and regularization loss is 6.792304.
#  Top K precision = 0.08934426229508197, recall = 0.007349324274260472.
# Training on epoch 4 minibatch 311/391 completed
#  bpr_loss on current minibatch is 7.469471, and regularization loss is 6.775776.
#  Top K precision = 0.07931034482758617, recall = 0.005421758110739721.
# Training on epoch 4 minibatch 321/391 completed
#  bpr_loss on current minibatch is 7.188107, and regularization loss is 6.496225.
#  Top K precision = 0.07719298245614031, recall = 0.007161053017674382.
# Training on epoch 4 minibatch 331/391 completed
#  bpr_loss on current minibatch is 7.317118, and regularization loss is 6.623445.
#  Top K precision = 0.08067226890756299, recall = 0.005746690990136948.
# Training on epoch 4 minibatch 341/391 completed
#  bpr_loss on current minibatch is 7.230257, and regularization loss is 6.536103.
#  Top K precision = 0.07596153846153843, recall = 0.0069173742894210405.
# Training on epoch 4 minibatch 351/391 completed
#  bpr_loss on current minibatch is 7.470497, and regularization loss is 6.778187.
#  Top K precision = 0.0869565217391304, recall = 0.005541160892705156.
# Training on epoch 4 minibatch 361/391 completed
#  bpr_loss on current minibatch is 7.281054, and regularization loss is 6.587612.
#  Top K precision = 0.09115044247787606, recall = 0.0063476865711081555.
# Training on epoch 4 minibatch 371/391 completed
#  bpr_loss on current minibatch is 7.025841, and regularization loss is 6.332639.
#  Top K precision = 0.07129629629629629, recall = 0.005386643033342097.
# Training on epoch 4 minibatch 381/391 completed
#  bpr_loss on current minibatch is 6.993071, and regularization loss is 6.299616.
#  Top K precision = 0.09913043478260865, recall = 0.007380850463466593.
# Training on epoch 4 minibatch 391/391 completed
#  bpr_loss on current minibatch is 7.172271, and regularization loss is 6.47893.
#  Top K precision = 0.08961038961038957, recall = 0.00694448548044241.
#
# Training on 4 epoch completed.
#  Average bpr_loss on train set is 0.062742 for the current epoch.
#  Training top K precision = 0.04240000000000004, recall = 0.003540702938486795.
#  Average bpr_loss on the validation set is 0.000143, and regularization loss is 0.000129.
#  Validation top K precision = 0.03239999999999994, recall = 0.0024290999583336933.
#
# Training on the 5 epoch
# Training on epoch 5 minibatch 1/391 completed
#  bpr_loss on current minibatch is 7.121223, and regularization loss is 6.42802.
#  Top K precision = 0.0734513274336283, recall = 0.005275016248321495.
# Training on epoch 5 minibatch 11/391 completed
#  bpr_loss on current minibatch is 7.124781, and regularization loss is 6.43137.
#  Top K precision = 0.087719298245614, recall = 0.00673525085734032.
# Training on epoch 5 minibatch 21/391 completed
#  bpr_loss on current minibatch is 6.892083, and regularization loss is 6.198846.
#  Top K precision = 0.07280701754385964, recall = 0.005936542587698258.
# Training on epoch 5 minibatch 31/391 completed
#  bpr_loss on current minibatch is 6.893905, and regularization loss is 6.20134.
#  Top K precision = 0.08108108108108104, recall = 0.006085177916309182.
# Training on epoch 5 minibatch 41/391 completed
#  bpr_loss on current minibatch is 6.892257, and regularization loss is 6.199966.
#  Top K precision = 0.07207207207207204, recall = 0.00651606252447903.
# Training on epoch 5 minibatch 51/391 completed
#  bpr_loss on current minibatch is 6.823478, and regularization loss is 6.130115.
#  Top K precision = 0.09831932773109239, recall = 0.007356859202713658.
# Training on epoch 5 minibatch 61/391 completed
#  bpr_loss on current minibatch is 6.947194, and regularization loss is 6.253758.
#  Top K precision = 0.08859649122807016, recall = 0.007054643666925538.
# Training on epoch 5 minibatch 71/391 completed
#  bpr_loss on current minibatch is 6.812936, and regularization loss is 6.119579.
#  Top K precision = 0.08947368421052627, recall = 0.006809524813548764.
# Training on epoch 5 minibatch 81/391 completed
#  bpr_loss on current minibatch is 7.019464, and regularization loss is 6.327796.
#  Top K precision = 0.11160714285714282, recall = 0.007215075768106448.
# Training on epoch 5 minibatch 91/391 completed
#  bpr_loss on current minibatch is 6.797454, and regularization loss is 6.103963.
#  Top K precision = 0.08070175438596487, recall = 0.005734696898217491.
# Training on epoch 5 minibatch 101/391 completed
#  bpr_loss on current minibatch is 6.663796, and regularization loss is 5.970743.
#  Top K precision = 0.0787037037037037, recall = 0.007281369620966102.
# Training on epoch 5 minibatch 111/391 completed
#  bpr_loss on current minibatch is 6.626146, and regularization loss is 5.933105.
#  Top K precision = 0.09537037037037034, recall = 0.00816262948407031.
# Training on epoch 5 minibatch 121/391 completed
#  bpr_loss on current minibatch is 6.537153, and regularization loss is 5.84355.
#  Top K precision = 0.08596491228070173, recall = 0.006467357120042365.
# Training on epoch 5 minibatch 131/391 completed
#  bpr_loss on current minibatch is 6.561599, and regularization loss is 5.869589.
#  Top K precision = 0.09210526315789469, recall = 0.007238172906748283.
# Training on epoch 5 minibatch 141/391 completed
#  bpr_loss on current minibatch is 6.684039, and regularization loss is 5.989991.
#  Top K precision = 0.08376068376068371, recall = 0.0072245807198984165.
# Training on epoch 5 minibatch 151/391 completed
#  bpr_loss on current minibatch is 6.569192, and regularization loss is 5.875544.
#  Top K precision = 0.1081818181818181, recall = 0.00783839453764785.
# Training on epoch 5 minibatch 161/391 completed
#  bpr_loss on current minibatch is 6.603901, and regularization loss is 5.910583.
#  Top K precision = 0.08623853211009172, recall = 0.008769092694113849.
# Training on epoch 5 minibatch 171/391 completed
#  bpr_loss on current minibatch is 6.246007, and regularization loss is 5.552703.
#  Top K precision = 0.10265486725663711, recall = 0.007214848460349086.
# Training on epoch 5 minibatch 181/391 completed
#  bpr_loss on current minibatch is 6.250909, and regularization loss is 5.557415.
#  Top K precision = 0.07438016528925616, recall = 0.006940592341980027.
# Training on epoch 5 minibatch 191/391 completed
#  bpr_loss on current minibatch is 6.701783, and regularization loss is 6.007598.
#  Top K precision = 0.08558558558558556, recall = 0.006497297925254875.
# Training on epoch 5 minibatch 201/391 completed
#  bpr_loss on current minibatch is 6.424928, and regularization loss is 5.732175.
#  Top K precision = 0.09158878504672893, recall = 0.006621225855177147.
# Training on epoch 5 minibatch 211/391 completed
#  bpr_loss on current minibatch is 6.353612, and regularization loss is 5.660156.
#  Top K precision = 0.09736842105263153, recall = 0.008547702939671295.
# Training on epoch 5 minibatch 221/391 completed
#  bpr_loss on current minibatch is 6.366908, and regularization loss is 5.674222.
#  Top K precision = 0.09396551724137926, recall = 0.008409538286577558.
# Training on epoch 5 minibatch 231/391 completed
#  bpr_loss on current minibatch is 6.241221, and regularization loss is 5.54774.
#  Top K precision = 0.09363636363636361, recall = 0.006135758607615447.
# Training on epoch 5 minibatch 241/391 completed
#  bpr_loss on current minibatch is 5.952488, and regularization loss is 5.259876.
#  Top K precision = 0.08999999999999996, recall = 0.007011320724892542.
# Training on epoch 5 minibatch 251/391 completed
#  bpr_loss on current minibatch is 5.779963, and regularization loss is 5.086331.
#  Top K precision = 0.07075471698113205, recall = 0.0069970105986381665.
# ...
#  Top K precision = 0.07982456140350876, recall = 0.0058377859935067515.
# Training on epoch 8 minibatch 41/391 completed
#  bpr_loss on current minibatch is 3.32163, and regularization loss is 2.62808.
#  Top K precision = 0.07583333333333328, recall = 0.006786904822178862.
# Training on epoch 8 minibatch 51/391 completed
#  bpr_loss on current minibatch is 3.274309, and regularization loss is 2.581095.
#  Top K precision = 0.0645454545454545, recall = 0.006467995995668007.
# Training on epoch 8 minibatch 61/391 completed
#  bpr_loss on current minibatch is 3.595067, and regularization loss is 2.902005.
#  Top K precision = 0.08918918918918912, recall = 0.0072460518647778985.
# Training on epoch 8 minibatch 71/391 completed
#  bpr_loss on current minibatch is 3.396896, and regularization loss is 2.703598.
#  Top K precision = 0.0844036697247706, recall = 0.006578076026986474.
# Training on epoch 8 minibatch 81/391 completed
#  bpr_loss on current minibatch is 3.526221, and regularization loss is 2.833062.
#  Top K precision = 0.09821428571428567, recall = 0.006822245199434221.
# Training on epoch 8 minibatch 91/391 completed
#  bpr_loss on current minibatch is 3.217814, and regularization loss is 2.524548.
#  Top K precision = 0.09999999999999996, recall = 0.008271546466008944.
# Training on epoch 8 minibatch 101/391 completed
#  bpr_loss on current minibatch is 3.218306, and regularization loss is 2.525266.
#  Top K precision = 0.09374999999999999, recall = 0.007608486763087098.
# Training on epoch 8 minibatch 111/391 completed
#  bpr_loss on current minibatch is 3.351914, and regularization loss is 2.658615.
#  Top K precision = 0.08482142857142856, recall = 0.0068016928016793885.
# Training on epoch 8 minibatch 121/391 completed
#  bpr_loss on current minibatch is 3.359605, and regularization loss is 2.666549.
#  Top K precision = 0.10347826086956514, recall = 0.008637992123793214.
# Training on epoch 8 minibatch 131/391 completed
#  bpr_loss on current minibatch is 3.305963, and regularization loss is 2.612468.
#  Top K precision = 0.08534482758620685, recall = 0.007729284434412759.
# Training on epoch 8 minibatch 141/391 completed
#  bpr_loss on current minibatch is 3.132707, and regularization loss is 2.439756.
#  Top K precision = 0.07522935779816511, recall = 0.007141122709209628.
# Training on epoch 8 minibatch 151/391 completed
#  bpr_loss on current minibatch is 2.784801, and regularization loss is 2.091608.
#  Top K precision = 0.08571428571428567, recall = 0.006726139533186361.
# Training on epoch 8 minibatch 161/391 completed
#  bpr_loss on current minibatch is 3.556893, and regularization loss is 2.863854.
#  Top K precision = 0.0981818181818181, recall = 0.007409353721411128.
# Training on epoch 8 minibatch 171/391 completed
#  bpr_loss on current minibatch is 2.845227, and regularization loss is 2.152123.
#  Top K precision = 0.08434782608695648, recall = 0.006836213087485604.
# Training on epoch 8 minibatch 181/391 completed
#  bpr_loss on current minibatch is 3.199877, and regularization loss is 2.506728.
#  Top K precision = 0.08495575221238937, recall = 0.006577771027907997.
# Training on epoch 8 minibatch 191/391 completed
#  bpr_loss on current minibatch is 3.36188, and regularization loss is 2.668669.
#  Top K precision = 0.08608695652173909, recall = 0.006239601122987111.
# Training on epoch 8 minibatch 201/391 completed
#  bpr_loss on current minibatch is 3.083999, and regularization loss is 2.391341.
#  Top K precision = 0.07368421052631575, recall = 0.00735485362519451.
# Training on epoch 8 minibatch 211/391 completed
#  bpr_loss on current minibatch is 2.992341, and regularization loss is 2.299047.
#  Top K precision = 0.0839285714285714, recall = 0.005934045681726029.
# Training on epoch 8 minibatch 221/391 completed
#  bpr_loss on current minibatch is 2.845628, and regularization loss is 2.15217.
#  Top K precision = 0.07931034482758617, recall = 0.007599584171122634.
# Training on epoch 8 minibatch 231/391 completed
#  bpr_loss on current minibatch is 2.911118, and regularization loss is 2.217938.
#  Top K precision = 0.09473684210526313, recall = 0.0068124084964937895.
# Training on epoch 8 minibatch 241/391 completed
#  bpr_loss on current minibatch is 3.327034, and regularization loss is 2.633732.
#  Top K precision = 0.0895652173913043, recall = 0.007022482399916484.
# Training on epoch 8 minibatch 251/391 completed
#  bpr_loss on current minibatch is 2.908514, and regularization loss is 2.215459.
#  Top K precision = 0.07627118644067793, recall = 0.0055391005186273086.
# Training on epoch 8 minibatch 261/391 completed
#  bpr_loss on current minibatch is 3.162778, and regularization loss is 2.469662.
#  Top K precision = 0.08260869565217384, recall = 0.008314053436017998.
# Training on epoch 8 minibatch 271/391 completed
#  bpr_loss on current minibatch is 2.842513, and regularization loss is 2.14942.
#  Top K precision = 0.0939130434782608, recall = 0.007170355151847264.
# Training on epoch 8 minibatch 281/391 completed
#  bpr_loss on current minibatch is 3.064892, and regularization loss is 2.371867.
#  Top K precision = 0.10450450450450444, recall = 0.00735462048082501.
# Training on epoch 8 minibatch 291/391 completed
#  bpr_loss on current minibatch is 3.026441, and regularization loss is 2.333388.
#  Top K precision = 0.0927272727272727, recall = 0.0073246690112711175.
# Training on epoch 8 minibatch 301/391 completed
#  bpr_loss on current minibatch is 2.610789, and regularization loss is 1.917792.
#  Top K precision = 0.09459459459459454, recall = 0.007763772424529966.
# Training on epoch 8 minibatch 311/391 completed
#  bpr_loss on current minibatch is 3.081227, and regularization loss is 2.388041.
#  Top K precision = 0.07943925233644857, recall = 0.006621025024313843.
# Training on epoch 8 minibatch 321/391 completed
#  bpr_loss on current minibatch is 3.180135, and regularization loss is 2.486982.
#  Top K precision = 0.08907563025210079, recall = 0.006448110463340635.
# Training on epoch 8 minibatch 331/391 completed
#  bpr_loss on current minibatch is 3.010565, and regularization loss is 2.317493.
#  Top K precision = 0.07948717948717945, recall = 0.006988017152504311.
# Training on epoch 8 minibatch 341/391 completed
#  bpr_loss on current minibatch is 2.654262, and regularization loss is 1.961103.
#  Top K precision = 0.07948717948717943, recall = 0.006564531881964271.
# Training on epoch 8 minibatch 351/391 completed
#  bpr_loss on current minibatch is 3.02902, and regularization loss is 2.33592.
#  Top K precision = 0.09743589743589738, recall = 0.006492666156913412.
# Training on epoch 8 minibatch 361/391 completed
#  bpr_loss on current minibatch is 2.98849, and regularization loss is 2.295174.
#  Top K precision = 0.10172413793103444, recall = 0.0067952071148294655.
# Training on epoch 8 minibatch 371/391 completed
#  bpr_loss on current minibatch is 2.826764, and regularization loss is 2.133779.
#  Top K precision = 0.0911504424778761, recall = 0.0075920902830180536.
# Training on epoch 8 minibatch 381/391 completed
#  bpr_loss on current minibatch is 2.763481, and regularization loss is 2.070511.
#  Top K precision = 0.08879310344827583, recall = 0.006905212169372102.
# Training on epoch 8 minibatch 391/391 completed
#  bpr_loss on current minibatch is 2.784179, and regularization loss is 2.090779.
#  Top K precision = 0.0893333333333333, recall = 0.0075504030585492555.
#
# Training on 8 epoch completed.
#  Average bpr_loss on train set is 0.024558 for the current epoch.
#  Training top K precision = 0.04720000000000006, recall = 0.00406090658334189.
#  Average bpr_loss on the validation set is 5.8e-05, and regularization loss is 4.4e-05.
#  Validation top K precision = 0.03279999999999995, recall = 0.0024922129858567376.
#
# Training on the 9 epoch
# Training on epoch 9 minibatch 1/391 completed
#  bpr_loss on current minibatch is 2.65767, and regularization loss is 1.964611.
#  Top K precision = 0.07807017543859646, recall = 0.008073121288179885.
# Training on epoch 9 minibatch 11/391 completed
#  bpr_loss on current minibatch is 2.914266, and regularization loss is 2.221084.
#  Top K precision = 0.08782608695652169, recall = 0.006818471410940754.
# Training on epoch 9 minibatch 21/391 completed
#  bpr_loss on current minibatch is 2.851945, and regularization loss is 2.15888.
#  Top K precision = 0.09292035398230085, recall = 0.006472402873409413.
# Training on epoch 9 minibatch 31/391 completed
#  bpr_loss on current minibatch is 2.746885, and regularization loss is 2.053634.
#  Top K precision = 0.0897435897435897, recall = 0.006389265378811564.
# Training on epoch 9 minibatch 41/391 completed
#  bpr_loss on current minibatch is 2.751157, and regularization loss is 2.058417.
#  Top K precision = 0.08596491228070172, recall = 0.0066382751962129685.
# Training on epoch 9 minibatch 51/391 completed
#  bpr_loss on current minibatch is 2.752864, and regularization loss is 2.059571.
#  Top K precision = 0.09912280701754383, recall = 0.008838167001747046.
# Training on epoch 9 minibatch 61/391 completed
#  bpr_loss on current minibatch is 2.824657, and regularization loss is 2.131426.
#  Top K precision = 0.07636363636363636, recall = 0.007023260540963144.
# Training on epoch 9 minibatch 71/391 completed
#  bpr_loss on current minibatch is 2.868152, and regularization loss is 2.175052.
#  Top K precision = 0.09741379310344823, recall = 0.006945648607357887.
# Training on epoch 9 minibatch 81/391 completed
#  bpr_loss on current minibatch is 2.831747, and regularization loss is 2.138615.
#  Top K precision = 0.09999999999999998, recall = 0.006624089970457861.
# Training on epoch 9 minibatch 91/391 completed
#  bpr_loss on current minibatch is 2.749634, and regularization loss is 2.056555.
#  Top K precision = 0.0884955752212389, recall = 0.0062374277024001374.
# Training on epoch 9 minibatch 101/391 completed
#  bpr_loss on current minibatch is 2.603546, and regularization loss is 1.910573.
#  Top K precision = 0.06874999999999999, recall = 0.006334541199354242.
# Training on epoch 9 minibatch 111/391 completed
#  bpr_loss on current minibatch is 2.466884, and regularization loss is 1.773813.
#  Top K precision = 0.07499999999999996, recall = 0.006524953187627589.
# Training on epoch 9 minibatch 121/391 completed
#  bpr_loss on current minibatch is 2.872458, and regularization loss is 2.179192.
#  Top K precision = 0.08611111111111107, recall = 0.00677807427001308.
# Training on epoch 9 minibatch 131/391 completed
#  bpr_loss on current minibatch is 2.657681, and regularization loss is 1.964508.
#  Top K precision = 0.08157894736842101, recall = 0.00851598380020903.
# Training on epoch 9 minibatch 141/391 completed
#  bpr_loss on current minibatch is 2.473849, and regularization loss is 1.780741.
#  Top K precision = 0.0972477064220183, recall = 0.0075506699974272045.
# Training on epoch 9 minibatch 151/391 completed
#  bpr_loss on current minibatch is 2.803489, and regularization loss is 2.110369.
#  Top K precision = 0.09999999999999992, recall = 0.009168287146927946.
# Training on epoch 9 minibatch 161/391 completed
#  bpr_loss on current minibatch is 2.766187, and regularization loss is 2.073107.
#  Top K precision = 0.0848214285714285, recall = 0.007501772770599726.
# Training on epoch 9 minibatch 171/391 completed
#  bpr_loss on current minibatch is 2.459924, and regularization loss is 1.76661.
#  Top K precision = 0.08558558558558552, recall = 0.006801127936029801.
# Training on epoch 9 minibatch 181/391 completed
#  bpr_loss on current minibatch is 2.56483, and regularization loss is 1.871689.
#  Top K precision = 0.09043478260869564, recall = 0.006090408502657274.
# Training on epoch 9 minibatch 191/391 completed
#  bpr_loss on current minibatch is 2.510088, and regularization loss is 1.81709.
#  Top K precision = 0.08684210526315782, recall = 0.007267799005783623.
# Training on epoch 9 minibatch 201/391 completed
#  bpr_loss on current minibatch is 2.583385, and regularization loss is 1.890221.
#  Top K precision = 0.08288288288288288, recall = 0.006291035529668152.
# Training on epoch 9 minibatch 211/391 completed
#  bpr_loss on current minibatch is 2.586942, and regularization loss is 1.893928.
#  Top K precision = 0.08198198198198196, recall = 0.00712904332676324.
# Training on epoch 9 minibatch 221/391 completed
#  bpr_loss on current minibatch is 2.638345, and regularization loss is 1.945204.
#  Top K precision = 0.06785714285714282, recall = 0.0051227276895744875.
# Training on epoch 9 minibatch 231/391 completed
#  bpr_loss on current minibatch is 2.596245, and regularization loss is 1.903025.
#  Top K precision = 0.08644067796610166, recall = 0.006191249160401518.
# Training on epoch 9 minibatch 241/391 completed
#  bpr_loss on current minibatch is 2.44615, and regularization loss is 1.753059.
#  Top K precision = 0.0862068965517241, recall = 0.006338246701391075.
# Training on epoch 9 minibatch 251/391 completed
#  bpr_loss on current minibatch is 2.39563, and regularization loss is 1.702308.
#  Top K precision = 0.08644067796610168, recall = 0.00722684813351104.
# Training on epoch 9 minibatch 261/391 completed
#  bpr_loss on current minibatch is 2.566358, and regularization loss is 1.873137.
#  Top K precision = 0.08347826086956515, recall = 0.0055264235704516485.
# Training on epoch 9 minibatch 271/391 completed
#  bpr_loss on current minibatch is 2.448427, and regularization loss is 1.755328.
#  Top K precision = 0.09827586206896541, recall = 0.009344816371910059.
# Training on epoch 9 minibatch 281/391 completed
#  bpr_loss on current minibatch is 2.4689, and regularization loss is 1.775615.
#  Top K precision = 0.08141592920353977, recall = 0.007961017901664376.
# Training on epoch 9 minibatch 291/391 completed
#  bpr_loss on current minibatch is 2.261077, and regularization loss is 1.568023.
#  Top K precision = 0.08534482758620685, recall = 0.007488321055498888.
# Training on epoch 9 minibatch 301/391 completed
#  bpr_loss on current minibatch is 2.603968, and regularization loss is 1.910727.
#  Top K precision = 0.08017241379310341, recall = 0.007184207874625574.
# Training on epoch 9 minibatch 311/391 completed
#  bpr_loss on current minibatch is 2.402624, and regularization loss is 1.709504.
#  Top K precision = 0.08124999999999996, recall = 0.006560478992289726.
# Training on epoch 9 minibatch 321/391 completed
#  bpr_loss on current minibatch is 2.201416, and regularization loss is 1.508151.
#  Top K precision = 0.08859649122807016, recall = 0.0071565472197445135.
# Training on epoch 9 minibatch 331/391 completed
#  bpr_loss on current minibatch is 2.532205, and regularization loss is 1.839053.
#  Top K precision = 0.08474576271186433, recall = 0.00696888944731032.
# Training on epoch 9 minibatch 341/391 completed
#  bpr_loss on current minibatch is 2.200582, and regularization loss is 1.507397.
#  Top K precision = 0.07068965517241375, recall = 0.005884171460168556.
# Training on epoch 9 minibatch 351/391 completed
#  bpr_loss on current minibatch is 2.321597, and regularization loss is 1.628466.
#  Top K precision = 0.07657657657657653, recall = 0.005748123584247333.
# Training on epoch 9 minibatch 361/391 completed
#  bpr_loss on current minibatch is 2.499583, and regularization loss is 1.806374.
#  Top K precision = 0.08666666666666661, recall = 0.005751258786839347.
# Training on epoch 9 minibatch 371/391 completed
#  bpr_loss on current minibatch is 2.405843, and regularization loss is 1.712696.
#  Top K precision = 0.0745614035087719, recall = 0.006306760324873673.
# Training on epoch 9 minibatch 381/391 completed
#  bpr_loss on current minibatch is 2.046486, and regularization loss is 1.353417.
#  Top K precision = 0.0855855855855855, recall = 0.007401461249343696.
# Training on epoch 9 minibatch 391/391 completed
#  bpr_loss on current minibatch is 2.019472, and regularization loss is 1.326256.
#  Top K precision = 0.06712328767123288, recall = 0.0056255203755461725.
#
# Training on 9 epoch completed.
#  Average bpr_loss on train set is 0.020022 for the current epoch.
#  Training top K precision = 0.046000000000000034, recall = 0.004031551924071668.
#  Average bpr_loss on the validation set is 4.8e-05, and regularization loss is 3.5e-05.
#  Validation top K precision = 0.03279999999999995, recall = 0.0024954735767687424.

# %% [markdown]
# ### Plot top K precision over epochs

# %%
plt.plot(epochs_tracked, [precision for precision, _ in train_topks],
         label="Train")
plt.plot(epochs_tracked, [precision for precision, _ in val_topks],
         label="Val")
plt.ylabel(f"Top {K} precision")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ### Plot top K recall over epochs

# %%
plt.plot(epochs_tracked, [recall for _, recall in train_topks],
         label="Train")
plt.plot(epochs_tracked, [recall for _, recall in val_topks],
         label="Val")
plt.ylabel(f"Top {K} recall")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## Test
#
# After training, let's test our model on the test set.

# %%
# predict on the test set
lightGCN.eval()
print("Training completed after {} epochs".format(epochs))

users_test = samples_test[:, 0:1]
pos_test = samples_test[:, 1:2]
neg_test = samples_test[:, 2:3]

loss_test, reg_loss_test = bpr_loss(
    lightGCN, users_test, pos_test, neg_test, data, test_mask)
reg_loss_test = reg_loss_test * weight_decay

# predict on the test set
user_indices = samples_test[:, 0]
user_indices = user_indices.repeat(2).long()
item_indices = torch.cat((samples_test[:, 1], samples_test[:, 2])).long()
pred_test = getUsersRating(lightGCN, users_test[:,0], data)\
    [user_indices, item_indices]
truth_test = data["edge_index"][users_test.long()[:,0]]\
    [user_indices, item_indices]
test_topk_precision, test_topk_recall = personalized_topk(
    pred_test, K, user_indices, data["edge_index"])

print("Average bpr_loss on the test set is {}, and regularization loss is {}.\n".format(round(float((loss_test+reg_loss_test)/len(samples_test)), 6),
                                                                                                round(float(reg_loss_test/len(samples_test)), 6)),
      "Top K precision = {}, recall = {}.".format(test_topk_precision, test_topk_recall))

# Save model embeddings.
torch.save(lightGCN, config_dict["model_name"])
# Out:
# Training completed after 10 epochs
# Average bpr_loss on the test set is 4.9e-05, and regularization loss is 3.6e-05.
#  Top K precision = 0.03459999999999996, recall = 0.0026493808033223273.

# %% [markdown]
# # Run matrix factorization as baseline performance
#
# As a baseline, we can run [PARAFAC matrix factorization](https://www.sciencedirect.com/science/article/abs/pii/S0169743997000324) on the dataset. We use the [TensorLy](http://tensorly.org/dev/modules/generated/tensorly.decomposition.parafac.html#tensorly.decomposition.parafac) library.

# %%
def matrix_factorization(user_item, rank):
    """Runs matrix factorization on `user_item` and get user-item similarities.

    Args:
        user_item: User-item connectivity matrix.
        rank: Number of numbers to represent a user / item.

    Returns:
        User-item similarities.
    """
    weights, (user_factors, item_factors) = \
        decomposition.parafac(user_item, rank)
    similarities = user_factors @ item_factors.T
    return 1 / (1 + np.exp(- similarities))

# %% [markdown]
# We observe that our LightGCN model delivers betters performance than matrix factorization.

# %%
# Compute baseline metrics using matrix factorization.
baseline_pred = matrix_factorization(
        data["edge_index"].detach().cpu().numpy(),
        config_dict["mf_rank"])[user_indices.cpu(), item_indices.cpu()]
baseline_topk_precision, baseline_topk_recall = \
        personalized_topk(baseline_pred, K, user_indices, data["edge_index"])
print("Baseline (PARAFAC matrix factorization) produces ",
      "Top K precision = {}, recall = {}.".format(baseline_topk_precision,
                                                  baseline_topk_recall))
# Out:
# Baseline (PARAFAC matrix factorization) produces  Top K precision = 0.04180000000000001, recall = 0.002972668630156378.
