# %% [markdown]
# # **Movie Recommendation with LightGCN✨**
#
#
# This notebook walks you through building a movie recommendation system using LightGCN. You can read more about Graph Neural Networks (GNNs), LightGCN and movie recommendation in [this Medium tutorial](https://medium.com/@quinn.wang/eb6d112f1e8).
#
# By Qinchen Wang, Xiaoli Yang, Feiyang (Kathy) Yu as part of the Stanford [CS224W: Machine Learning with Graphs](http://web.stanford.edu/class/cs224w/) course project.
#
# Without further ado, let's get started!

# %% [markdown]
# # Setup
#
# We recommend using a hardware accelerator for the notebook. You can set a GPU via "Runtime" --> "Change runtime type".

# %%
# !pip install tensorly
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install torch-spline-conv -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install torch-geometric

# %%
import collections
import math
import os
import os.path as osp
from tqdm import tqdm
from typing import List
import random
import time
import zipfile

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.options.display.max_rows = 10
from sklearn import metrics
from tensorly import decomposition

import torch
from torch.functional import tensordot
from torch import nn, optim, Tensor
import torch_geometric
from torch_geometric.data import Dataset, Data, download_url, extract_zip
from torch_geometric.nn import MessagePassing
from torch_geometric.typing import Adj
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
print(f"PyTorch has version {torch.__version__}")
print(f"Torch version: {torch.__version__}")
print(f"Cuda available: {torch.cuda.is_available()}")
print(f"Torch geometric version: {torch_geometric.__version__}")
# Out:
# PyTorch has version 2.6.0+cu118
# Torch version: 2.6.0+cu118
# Cuda available: True
# Torch geometric version: 2.6.1

# %% [markdown]
# # Configurations
#
# Configure the model and training process. These parameters will make more sense as you move along.

# %%
rating_threshold = 3  #@param {type: "integer"}: Ratings equal to or greater than 3 are positive items.

config_dict = {
    "num_samples_per_user": 100,
    "num_users": 800,

    "epochs": 70,
    "batch_size": 1024,
    "lr": 0.001,
    "weight_decay": 0.01,

    "embedding_size": 64,
    "num_layers": 3,
    "K": 10,
    "mf_rank": 8,

    "minibatch_per_print": 10,
    "epochs_per_print": 1,

    "val_frac": 0.2,
    "test_frac": 0.1,

    "model_name": "model.pth"
}

# %% [markdown]
# # Dataset
#
# A great publicly available dataset for training movie recommenders is the MovieLens 1M dataset. The MovieLens 1M dataset consists of 1 million movie ratings of score 1 to 5, from 6000 users and 4000 movies.

# %%
DATA_PATH = "https://files.grouplens.org/datasets/movielens/ml-1m.zip"

# %%
def trans_ml(dat, thres):
    """
    Transform function that assign non-negative entries >= thres 1, and non-
    negative entries <= thres 0. Keep other entries the same.
    """
    thres = thres[0]
    matrix = dat['edge_index']
    matrix[(matrix < thres) & (matrix > -1)] = 0
    matrix[(matrix >= thres)] = 1
    dat['edge_index'] = matrix
    return dat


class MovieLens(Dataset):
    def __init__(self, root, transform=None, pre_transform=None,
            transform_args=None, pre_transform_args=None):
        """
        root = where the dataset should be stored. This folder is split
        into raw_dir (downloaded dataset) and processed_dir (process data).
        """
        super(MovieLens, self).__init__(root, transform, pre_transform)
        self.transform = transform
        self.pre_transform = pre_transform
        self.transform_args = transform_args
        self.pre_transform_args = pre_transform_args

    @property
    def raw_file_names(self):
        return "ml-1m.zip"

    @property
    def processed_file_names(self):
        return ["data_movielens.pt"]

    def download(self):
        # Download to `self.raw_dir`.
        download_url(DATA_PATH, self.raw_dir)

    def _load(self):
        print(self.raw_dir)
        # extract_zip(self.raw_paths[0], self.raw_dir)
        with zipfile.ZipFile(self.raw_paths[0], 'r') as zip_ref:
            zip_ref.extractall(self.raw_dir)
        unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
        users = pd.read_table(self.raw_dir+'/ml-1m/users.dat',
                              sep='::', header=None, names=unames,
                              engine='python', encoding='latin-1')
        rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
        ratings = pd.read_table(self.raw_dir+'/ml-1m/ratings.dat', sep='::',
                                header=None, names=rnames, engine='python',
                                encoding='latin-1')
        mnames = ['movie_id', 'title', 'genres']
        movies = pd.read_table(self.raw_dir+'/ml-1m/movies.dat', sep='::',
                               header=None, names=mnames, engine='python',
                               encoding='latin-1')
        dat = pd.merge(pd.merge(ratings, users), movies)

        return users, ratings, movies, dat

    def process(self):
        print('run process')
        # load information from file
        users, ratings, movies, dat = self._load()

        users = users['user_id']
        movies = movies['movie_id']

        num_users = config_dict["num_users"]
        if num_users != -1:
            users = users[:num_users]

        user_ids = range(len(users))
        movie_ids = range(len(movies))

        user_to_id = dict(zip(users, user_ids))
        movie_to_id = dict(zip(movies, movie_ids))

        # get adjacency info
        self.num_user = users.shape[0]
        self.num_item = movies.shape[0]

        # initialize the adjacency matrix
        rat = torch.zeros(self.num_user, self.num_item)

        for index, row in ratings.iterrows():
            user, movie, rating = row[:3]
            if num_users != -1:
                if user not in user_to_id: break
            # create ratings matrix where (i, j) entry represents the ratings
            # of movie j given by user i.
            rat[user_to_id[user], movie_to_id[movie]] = rating

        # create Data object
        data = Data(edge_index = rat,
                    raw_edge_index = rat.clone(),
                    data = ratings,
                    users = users,
                    items = movies)

        # apply any pre-transformation
        if self.pre_transform is not None:
            data = self.pre_transform(data, self.pre_transform_args)

        # apply any post_transformation
        # if self.transform is not None:
        #     # data = self.transform(data, self.transform_args)
        data = self.transform(data, [rating_threshold])

        # save the processed data into .pt file
        torch.save(data, osp.join(self.processed_dir, f'data_movielens.pt'))
        print('process finished')

    def len(self):
        """
        return the number of examples in your graph
        """
        # TODO: how to define number of examples
        return

    def get(self):
        """
        The logic to load a single graph
        """
        data = torch.load(osp.join(self.processed_dir, 'data_movielens.pt'), weights_only=False)
        return data

    def train_val_test_split(self, val_frac=0.2, test_frac=0.1):
        """
        Return two mask matrices (M, N) that represents edges present in the
        train and validation set
        """
        try:
            self.num_user, self.num_item
        except AttributeError:
            data = self.get()
            self.num_user = len(data["users"].unique())
            self.num_item = len(data["items"].unique())
        # get number of edges masked for training and validation
        num_train_replaced = \
            round((test_frac+val_frac)*self.num_user*self.num_item)
        num_val_show = round(val_frac*self.num_user*self.num_item)

        # edges masked during training
        indices_user = np.random.randint(0, self.num_user, num_train_replaced)
        indices_item = np.random.randint(0, self.num_item, num_train_replaced)

        # sample part of edges from training stage to be unmasked during
        # validation
        indices_val_user = np.random.choice(indices_user, num_val_show)
        indices_val_item = np.random.choice(indices_item, num_val_show)

        train_mask = torch.ones(self.num_user, self.num_item)
        train_mask[indices_user, indices_item] = 0

        val_mask = train_mask.clone()
        val_mask[indices_val_user, indices_val_item] = 1

        test_mask = torch.ones_like(train_mask)

        return train_mask, val_mask, test_mask

# %% [markdown]
# # LightGCN implementation
#
# Now let's dive into the model!

# %% [markdown]
# ## LightGCN neiborhood aggregation layer
#
# Starting with the initial embeddings $E^{(0)}$ and the bipartite graph, we iterate over each node to perform neighborhood aggregation. Note that LightGCN uses **a simple weighted sum aggregator** and **avoids the heavy-lifting feature transformation and nonlinear activation**.
#
# Within each layer, for each user in the graph, we compute its updated embedding as the weighted sum of embeddings from all its neighboring items (movies) following the formula below:
# $$ \textbf{e}_u^{(k+1)} = \sum_{i \in N_u} \frac{1}{\sqrt{|N_u|} \sqrt{|N_i|}} \textbf{e}_i^{(k)} $$
# where $ \textbf{e}_u^{(k)} $ and $ \textbf{e}_i^{(k)} $ are the user and item (movie) node embeddings at the k-th layer. $ |N_u| $ and $ |N_i| $ are the user and item nodes’ number of neighbors.
#
# Similarly, for each item, the updated embedding is computed using weighted sum of its neighboring users:
# $$ \textbf{e}_i^{(k+1)} = \sum_{i \in N_i} \frac{1}{\sqrt{|N_i|} \sqrt{|N_u|}} \textbf{e}_u^{(k)} $$

# %%
class LightGCNConv(MessagePassing):
    r"""The neighbor aggregation operator from the `"LightGCN: Simplifying and
    Powering Graph Convolution Network for Recommendation"
    <https://arxiv.org/abs/2002.02126#>`_ paper

    Args:
        in_channels (int): Size of each input sample, or :obj:`-1` to derive
            the size from the first input(s) to the forward method.
        out_channels (int): Size of each output sample.
        num_users (int): Number of users for recommendation.
        num_items (int): Number of items to recommend.
        **kwargs (optional): Additional arguments of
            :class:`torch_geometric.nn.conv.MessagePassing`.
    """
    def __init__(self, in_channels: int, out_channels: int,
                 num_users: int, num_items: int, **kwargs):
        super(LightGCNConv, self).__init__(**kwargs)

        self.in_channels = in_channels
        self.out_channels = out_channels

        self.num_users = num_users
        self.num_items = num_items

        self.reset_parameters()

    def reset_parameters(self):
        pass  # There are no layer parameters to learn.

    def forward(self, x: Tensor, edge_index: Adj) -> Tensor:
        """Performs neighborhood aggregation for user/item embeddings."""
        user_item = \
                torch.zeros(self.num_users, self.num_items, device=x.device)
        user_item[edge_index[:, 0], edge_index[:, 1]] = 1
        user_neighbor_counts = torch.sum(user_item, axis=1)
        item_neightbor_counts = torch.sum(user_item, axis=0)
        # Compute weight for aggregation: 1 / sqrt(N_u * N_i)
        weights = user_item / torch.sqrt(
                user_neighbor_counts.repeat(self.num_items, 1).T \
                * item_neightbor_counts.repeat(self.num_users, 1))
        weights = torch.nan_to_num(weights, nan=0)
        out = torch.concat((weights.T @ x[:self.num_users],
                            weights @ x[self.num_users:]), 0)
        return out

    def __repr__(self):
        return '{}({}, {})'.format(self.__class__.__name__, self.in_channels,
                                   self.out_channels)

# %% [markdown]
# ## LightGCN model
#
# At layer combination, instead of taking the embedding of the final layer, LightGCN computes **a weighted sum of the embeddings at different layers**:
# $$ \textbf{e}_u = \sum_{k=0}^K \alpha_k \textbf{e}_u^{(k)} $$
# $$ \textbf{e}_i = \sum_{k=0}^K \alpha_k \textbf{e}_i^{(k)} $$
# with $ \alpha \ge 0 $. Here, alpha values can either be learned as network parameters, or set as empirical hyperparameters. It has been found that $ \alpha = \frac{1}{K + 1} $ works well.
#
# LightGCN predicts based on the inner product of the final user and item (movie) embeddings:
# $$ \hat{y}_{ui} = \textbf{e}_u^T \textbf{e}_i $$
# This inner product measures the similarity between the user and movie, therefore allowing us to understand how likely it is for the user to like the movie.

# %%
class LightGCN(nn.Module):
    def __init__(self,
                 config: dict,
                 device=None,
                 **kwargs):
        super().__init__()

        self.num_users  = config["n_users"]
        self.num_items  = config["m_items"]
        self.embedding_size = config["embedding_size"]
        self.in_channels = self.embedding_size
        self.out_channels = self.embedding_size
        self.num_layers = config["num_layers"]

        # 0-th layer embedding.
        self.embedding_user_item = torch.nn.Embedding(
            num_embeddings=self.num_users + self.num_items,
            embedding_dim=self.embedding_size)
        self.alpha = None

        # random normal init seems to be a better choice when lightGCN actually
        # don't use any non-linear activation function
        nn.init.normal_(self.embedding_user_item.weight, std=0.1)  # 均值为 1.5，标准差为 0.1
        print('use NORMAL distribution initilizer')

        self.f = nn.Sigmoid()

        self.convs = nn.ModuleList()
        self.convs.append(LightGCNConv(
                self.embedding_size, self.embedding_size,
                num_users=self.num_users, num_items=self.num_items, **kwargs))

        for _ in range(1, self.num_layers):
            self.convs.append(
                LightGCNConv(
                        self.embedding_size, self.embedding_size,
                        num_users=self.num_users, num_items=self.num_items,
                        **kwargs))

        self.device = None
        if device is not None:
            self.convs.to(device)
            self.device = device

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()

    def forward(self, x: Tensor, edge_index: Adj, *args, **kwargs) -> Tensor:
        xs: List[Tensor] = []

        edge_index = torch.nonzero(edge_index)
        for i in range(self.num_layers):
            x = self.convs[i](x, edge_index, *args, **kwargs)
            if self.device is not None:
                x = x.to(self.device)
            xs.append(x)
        xs = torch.stack(xs)

        self.alpha = 1 / (1 + self.num_layers) * torch.ones(xs.shape)
        if self.device is not None:
            self.alpha = self.alpha.to(self.device)
            xs = xs.to(self.device)
        x = (xs * self.alpha).sum(dim=0)  # Sum along K layers.
        return x

    def __repr__(self) -> str:
        return (f'{self.__class__.__name__}({self.in_channels}, '
                f'{self.out_channels}, num_layers={self.num_layers})')

# %% [markdown]
# ## Utility functions
#
# The utility functions allow us to retrieve embeddings and compute user-item similarities. These will become userful later on.

# %%
def getUsersRating(model, users, data):
    """ Get the embedding of users
    INPUT:
        model: the LightGCN model you are training on
        users: this is the user index (note: use 0-indexed and not user number,
            which is 1-indexed)
        data: the entire data, used to fetch all users and all items
    """
    all_users_items = model(model.embedding_user_item.weight.clone(),
                            data["edge_index"])
    all_users = all_users_items[:len(data["users"])]
    items_emb = all_users_items[len(data["users"]):]
    users_emb = all_users[users.long()]
    rating = model.f(torch.matmul(users_emb, items_emb.t()))
    return rating

def getEmbedding(model, users, pos, neg, data, mask):
    """
    INPUT:
        model: the LightGCN model you are training on
        users: this is the user index (note: use 0-indexed and not user number,
            which is 1-indexed)
        pos: positive index corresponding to an item that the user like
        neg: negative index corresponding to an item that the user doesn't like
        data: the entire data, used to fetch all users and all items
        mask: Masking matrix indicating edges present in the current
            train / validation / test set.
    """
    # assuming we always search for users and items by their indices (instead of
    # user/item number)
    all_users_items = model(model.embedding_user_item.weight.clone(),
                            data["edge_index"] * mask)
    all_users = all_users_items[:len(data["users"])]
    all_items = all_users_items[len(data["users"]):]
    users_emb = all_users[users]
    pos_emb = all_items[pos]
    neg_emb = all_items[neg]
    n_user = len(data["users"])
    users_emb_ego = model.embedding_user_item(users)
    # offset the index to fetch embedding from user_item
    pos_emb_ego = model.embedding_user_item(pos + n_user)
    neg_emb_ego = model.embedding_user_item(neg + n_user)
    return users_emb, pos_emb, neg_emb, users_emb_ego, pos_emb_ego, neg_emb_ego

# %% [markdown]
# ## Bayesian Personalized Ranking loss (BPR loss)
#
# To train the LightGCN model, we need an objective function that aligns with our goal for movie recommendation. We use the Bayesian Personalized Ranking (BPR) loss, which encourages observed user-item predictions to have increasingly higher values than unobserved ones, along with $ L_2 $ regularization:
# $$ L_{BPR} = - \sum_{u=1}^M \sum_{i \in N_u} \sum_{j \notin N_u} \ln \sigma(\hat{y}_{ui} - \hat{y}_{uj}) + \lambda ||\textbf{E}^{(0)} ||^2 $$
# where $ \textbf{E}^{(0)} $ is a matrix with column vectors being the 0-th layer embeddings to learn.

# %%
def bpr_loss(model, users, pos, neg, data, mask):
    """
    INPUT:
        model: the LightGCN model you are training on
        users: this is the user index (note: use 0-indexed and not user number,
            which is 1-indexed)
        pos: positive index corresponding to an item that the user like
            (0-indexed, note to index items starting from 0)
        neg: negative index corresponding to an item that the user doesn't like
        data: the entire data, used to fetch all users and all items
        mask: Masking matrix indicating edges present in the current
            train / validation / test set.
    OUTPUT:
        loss, reg_loss
    """
    # assuming we always sample the same number of positive and negative sample
    # per user
    assert len(users) == len(pos) and len(users) == len(neg)
    (users_emb, pos_emb, neg_emb,
    userEmb0,  posEmb0, negEmb0) = getEmbedding(model, users.long(), pos.long(),
                                                neg.long(), data, mask)
    reg_loss = (1/2)*(userEmb0.norm(2).pow(2) +
                        posEmb0.norm(2).pow(2)  +
                        negEmb0.norm(2).pow(2))/float(len(users))
    pos_scores = torch.mul(users_emb, pos_emb)
    pos_scores = torch.sum(pos_scores, dim=1)
    neg_scores = torch.mul(users_emb, neg_emb)
    neg_scores = torch.sum(neg_scores, dim=1)

    loss = torch.mean(torch.nn.functional.softplus(neg_scores - pos_scores))

    return loss, reg_loss

# %% [markdown]
# ## Personalized top K precision and recall
#
# To evaluate training progress and model performance, we compute the **top K precision and recall** scores. Specifically, for each user, we rank movie items in order of decreasing similarity and choose the best K to recommend. Then, we compute the precision and recall of those K recommendations against ground truth items that the user likes and dislikes.

# %%
def personalized_topk(pred, K, user_indices, edge_index):
    """Computes TopK precision and recall.

    Args:
        pred: Predicted similarities between user and item.
        K: Number of items to rank.
        user_indices: Indices of users for each prediction in `pred`.
        edge_index: User and item connection matrix.

    Returns:
        Average Top K precision and recall for users in `user_indices`.
    """
    per_user_preds = collections.defaultdict(list)
    for index, user in enumerate(user_indices):
        per_user_preds[user.item()].append(pred[index].item())
    precisions = 0.0
    recalls = 0.0
    for user, preds in per_user_preds.items():
        while len(preds) < K:
            preds.append(random.choice(range(edge_index.shape[1])))
        top_ratings, top_items = torch.topk(torch.tensor(preds), K)
        correct_preds = edge_index[user, top_items].sum().item()
        total_pos = edge_index[user].sum().item()
        precisions += correct_preds / K
        recalls += correct_preds / total_pos if total_pos != 0 else 0
    num_users = len(user_indices.unique())
    return precisions / num_users, recalls / num_users

# %% [markdown]
# # Training, validation and testing
#
# Now, let's train our LightGCN model, and run it on the validation and test sets.

# %% [markdown]
# ## Sampling
#
# For each user, we randomly sample $n$ positive-negative movie examples and add them to the training, validation or test set. $n$ is a parameter that we can specify and tune.

# %%
def _sample_pos_neg(data, mask, num_samples_per_user):
    """Samples (user, positive item, negative item) tuples per user.

    If a user does not have a postive (negative) item, we choose an item
    with unknown liking (an item without raw rating data).

    Args:
        data: Dataset object containing edge_index and raw ratings matrix.
        mask: Masking matrix indicating edges present in the current
            train / validation / test set.
        num_samples_per_user: Number of samples to generate for each user.

    Returns:
        torch.Tensor object of (user, positive item, negative item) samples.
    """
    print("=====Starting to sample=====")
    start = time.time()
    samples = []
    all_items = set(range(len(data["items"])))
    for user_index, user in enumerate(data["users"]):
        pos_items = set(
            torch.nonzero(data["edge_index"][user_index])[:, 0].tolist())
        unknown_items = all_items.difference(
                set(
                    torch.nonzero(
                        data["raw_edge_index"][user_index])[:, 0].tolist()))
        neg_items = all_items.difference(
            set(pos_items)).difference(set(unknown_items))
        unmasked_items = set(torch.nonzero(mask[user_index])[:, 0].tolist())
        if len(unknown_items.union(pos_items)) == 0 or \
                len(unknown_items.union(neg_items)) == 0:
            continue
        for _ in range(num_samples_per_user):
            if len(pos_items.intersection(unmasked_items)) == 0:
                pos_item_index = random.choice(
                    list(unknown_items.intersection(unmasked_items)))
            else:
                pos_item_index = random.choice(
                    list(pos_items.intersection(unmasked_items)))
            if len(neg_items.intersection(unmasked_items)) == 0:
                neg_item_index = random.choice(
                    list(unknown_items.intersection(unmasked_items)))
            else:
                neg_item_index = random.choice(
                    list(neg_items.intersection(unmasked_items)))
            samples.append((user_index, pos_item_index, neg_item_index))
    end = time.time()
    print(f"=====Sampling completed (took {end - start} seconds)=====")
    return torch.tensor(samples, dtype=torch.int32)

def sample_pos_neg(data, train_mask, val_mask, test_mask, num_samples_per_user):
    """Samples (user, positive item, negative item) tuples per user.

    If a user does not have a postive (negative) item, we choose an item
    with unknown liking (an item without raw rating data).

    Args:
        data: Dataset object containing edge_index and raw ratings matrix.
        train_mask: Masking matrix indicating edges present in train set.
        val_mask: Masking matrix indicating edges present in validation set.
        test_mask: Masking matrix indicating edges present in test set.
        num_samples_per_user: Number of samples to generate for each user.

    Returns:
        torch.Tensor object of (user, positive item, negative item) samples for
        train, validation and test.
    """
    train_samples = _sample_pos_neg(data, train_mask, num_samples_per_user)
    val_samples = _sample_pos_neg(data, val_mask, num_samples_per_user)
    test_samples = _sample_pos_neg(data, test_mask, num_samples_per_user)
    return train_samples, val_samples, test_samples

# %% [markdown]
# ## Training and validation
#
# Now, let's start training!

# %%
root = os.getcwd()
movielens = MovieLens(root=root, transform=trans_ml)
data = movielens.get()
train_mask, val_mask, test_mask = \
        movielens.train_val_test_split(val_frac=config_dict["val_frac"],
                                       test_frac=config_dict["test_frac"])

n_users = len(data["users"].unique())
m_items = len(data["items"].unique())
print(f"#Users: {n_users}")
print(f"#Items: {m_items}")

model_config = {
    "n_users": n_users,
    "m_items": m_items,
    "embedding_size": config_dict["embedding_size"],
    "num_layers": config_dict["num_layers"],
}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
lightGCN = LightGCN(model_config, device=device)

num_samples_per_user = config_dict["num_samples_per_user"]
epochs = config_dict["epochs"]
batch_size = config_dict["batch_size"]
lr = config_dict["lr"]
weight_decay = config_dict["weight_decay"]

K = config_dict["K"]

lightGCN.to(device)

samples_train, samples_val, samples_test = \
        sample_pos_neg(data, train_mask, val_mask, test_mask,
                       num_samples_per_user)

samples_train=samples_train.to(device)
samples_val=samples_val.to(device)
samples_test=samples_test.to(device)
train_mask=train_mask.to(device)
val_mask=val_mask.to(device)
test_mask=test_mask.to(device)
data = data.to(device)

print(f"#Training samples: {len(samples_train)}",
      f"#Validation samples: {len(samples_val)}",
      f"#Test samples: {len(samples_test)}")

optimizer = optim.Adam(lightGCN.parameters(), lr=lr)
print("Optimizer:", optimizer)

epochs_tracked = []
train_topks = []
val_topks = []

for epoch in range(epochs):
    print("Training on the {} epoch".format(epoch))
    lightGCN.train()
    loss_sum = 0
    # Shuffle the order of rows.
    samples_train = samples_train[torch.randperm(samples_train.size()[0])]
    for batch_idx in range(math.ceil(len(samples_train) / batch_size)):
        optimizer.zero_grad()

        current_batch = \
            samples_train[batch_idx*batch_size: (batch_idx+1)*batch_size]
        # Shuffle the order of rows.
        current_batch = current_batch[torch.randperm(current_batch.size()[0])]
        users = current_batch[:, 0:1]
        pos = current_batch[:, 1:2]
        neg = current_batch[:, 2:3]

        loss, reg_loss = bpr_loss(lightGCN, users, pos, neg, data,
                                  train_mask)
        reg_loss = reg_loss * weight_decay
        loss = loss + reg_loss
        loss_sum += loss.detach()

        loss.backward()
        optimizer.step()

        if batch_idx % config_dict["minibatch_per_print"] == 0:
            all_users = torch.linspace(start=0,
                                       end=n_users - 1, steps=n_users).long()
            user_indices = current_batch[:, 0]
            user_indices = user_indices.repeat(2).long() #對應pos、neg
            item_indices = torch.cat(
                (current_batch[:, 1], current_batch[:, 2])).long()
            pred = getUsersRating(lightGCN,
                                  all_users,
                                  data)[user_indices, item_indices]
            truth = data["edge_index"][user_indices, item_indices]
            topk_precision, topk_recall = \
                personalized_topk(pred, K, user_indices, data["edge_index"])

            print("Training on epoch {} minibatch {}/{} completed\n".format(epoch, batch_idx+1,
                                                                            math.ceil(len(samples_train) / batch_size)),
                  "bpr_loss on current minibatch is {}, and regularization loss is {}.\n".format(round(float(loss.detach().cpu()), 6),
                                                                                                 round(float(reg_loss.detach().cpu()), 6)),
                  "Top K precision = {}, recall = {}.".format(topk_precision, topk_recall))

    if epoch % config_dict["epochs_per_print"] == 0:
        epochs_tracked.append(epoch)

        # evaluation on both the trainisng and validation set
        lightGCN.eval()
        # predict on the training set
        users = samples_train[:, 0:1]
        user_indices = samples_train[:, 0]
        user_indices = user_indices.repeat(2).long()
        item_indices = torch.cat(
            (samples_train[:, 1], samples_train[:, 2])).long()
        pred = getUsersRating(lightGCN,
                              users[:,0],
                              data)[user_indices, item_indices]
        truth = data["edge_index"][users.long()[:,0]]\
            [user_indices, item_indices]
        train_topk_precision, train_topk_recall = \
            personalized_topk(pred, K, user_indices, data["edge_index"])
        train_topks.append((train_topk_precision, train_topk_recall))

        # predict on the validation set
        users_val = samples_val[:, 0:1]
        pos_val = samples_val[:, 1:2]
        neg_val = samples_val[:, 2:3]

        loss_val, reg_loss_val = bpr_loss(
            lightGCN, users_val, pos_val, neg_val, data, val_mask)
        reg_loss_val = reg_loss_val * weight_decay

        # predict on the validation set
        user_indices = samples_val[:, 0]
        user_indices = user_indices.repeat(2).long()
        item_indices = torch.cat((samples_val[:, 1], samples_val[:, 2])).long()
        pred_val = getUsersRating(lightGCN,
                                  users_val[:,0],
                                  data)[user_indices, item_indices]
        truth_val = data["edge_index"][users_val.long()[:,0]]\
            [user_indices, item_indices]
        val_topk_precision, val_topk_recall = \
            personalized_topk(pred_val, K, user_indices, data["edge_index"])
        val_topks.append((val_topk_precision, val_topk_recall))

        print("\nTraining on {} epoch completed.\n".format(epoch),
              "Average bpr_loss on train set is {} for the current epoch.\n".format(round(float(loss_sum/len(samples_train)), 6)),
              "Training top K precision = {}, recall = {}.\n".format(train_topk_precision, train_topk_recall),
              "Average bpr_loss on the validation set is {}, and regularization loss is {}.\n".format(round(float((loss_val+reg_loss_val)/len(samples_val)), 6),
                                                                                                      round(float(reg_loss_val/len(samples_val)), 6)),
              "Validation top K precision = {}, recall = {}.\n".format(val_topk_precision, val_topk_recall))
# Out:
# Processing...
# run process
# c:\Users\k0920\Documents\GitHub\RL_recommender\raw
# process finished
# #Users: 800
# #Items: 3883
# use NORMAL distribution initilizer
# =====Starting to sample=====
# Done!
# =====Sampling completed (took 1.5549981594085693 seconds)=====
# =====Starting to sample=====
# =====Sampling completed (took 1.5220026969909668 seconds)=====
# =====Starting to sample=====
# =====Sampling completed (took 1.4151997566223145 seconds)=====
# #Training samples: 80000 #Validation samples: 80000 #Test samples: 80000
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# Training on the 0 epoch
# Training on epoch 0 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.702826, and regularization loss is 0.009679.
#  Top K precision = 0.08682042833607938, recall = 0.0065652938563421715.
# Training on epoch 0 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.701705, and regularization loss is 0.008558.
#  Top K precision = 0.09333333333333356, recall = 0.007172016691823093.
# Training on epoch 0 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.700778, and regularization loss is 0.007631.
#  Top K precision = 0.08877551020408186, recall = 0.006560762167549256.
# Training on epoch 0 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.699906, and regularization loss is 0.006759.
#  Top K precision = 0.08959435626102312, recall = 0.006485871193752321.
# Training on epoch 0 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.699189, and regularization loss is 0.006042.
#  Top K precision = 0.08506151142355033, recall = 0.006407675096631308.
# Training on epoch 0 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.698551, and regularization loss is 0.005404.
#  Top K precision = 0.0862847222222225, recall = 0.006992650517507879.
# Training on epoch 0 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.697958, and regularization loss is 0.004811.
#  Top K precision = 0.08676975945017208, recall = 0.0066611998875853945.
# Training on epoch 0 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.697402, and regularization loss is 0.004254.
#  Top K precision = 0.09190140845070445, recall = 0.006977608978492778.
#
# Training on 0 epoch completed.
#  Average bpr_loss on train set is 0.000691 for the current epoch.
#  Training top K precision = 0.0462500000000001, recall = 0.0033921633694714206.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.03312500000000004, recall = 0.0024021340329640735.
#
# Training on the 1 epoch
# Training on epoch 1 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.697002, and regularization loss is 0.003855.
#  Top K precision = 0.08208191126279887, recall = 0.006097254517341198.
# Training on epoch 1 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.6966, and regularization loss is 0.003452.
#  Top K precision = 0.09187279151943485, recall = 0.006961369541462886.
# Training on epoch 1 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.696247, and regularization loss is 0.0031.
#  Top K precision = 0.08252595155709362, recall = 0.006843230991180865.
# Training on epoch 1 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.695908, and regularization loss is 0.002761.
#  Top K precision = 0.0839655172413795, recall = 0.006624227716683176.
# Training on epoch 1 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.69566, and regularization loss is 0.002513.
#  Top K precision = 0.0899480069324092, recall = 0.0073511261603112655.
# Training on epoch 1 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.695423, and regularization loss is 0.002276.
#  Top K precision = 0.08310104529616752, recall = 0.0069465773062735514.
# Training on epoch 1 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.695216, and regularization loss is 0.002069.
#  Top K precision = 0.08948275862068995, recall = 0.007001680929148641.
# Training on epoch 1 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.695014, and regularization loss is 0.001866.
#  Top K precision = 0.08771929824561427, recall = 0.006708791404352388.
#
# Training on 1 epoch completed.
#  Average bpr_loss on train set is 0.000687 for the current epoch.
#  Training top K precision = 0.04662500000000016, recall = 0.0039457944599571556.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.03362500000000005, recall = 0.0024627143362405467.
#
# Training on the 2 epoch
# Training on epoch 2 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.694806, and regularization loss is 0.001659.
#  Top K precision = 0.08728522336769785, recall = 0.0072786065768385075.
# Training on epoch 2 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.69466, and regularization loss is 0.001513.
#  Top K precision = 0.08838821490467964, recall = 0.0067662701628978805.
# Training on epoch 2 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.694508, and regularization loss is 0.001361.
#  Top K precision = 0.08737024221453311, recall = 0.006656568249299038.
# Training on epoch 2 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.694382, and regularization loss is 0.001234.
#  Top K precision = 0.08828671328671352, recall = 0.006887686274702376.
# Training on epoch 2 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.694259, and regularization loss is 0.001111.
#  Top K precision = 0.08868243243243268, recall = 0.00684582372584563.
# Training on epoch 2 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.694172, and regularization loss is 0.001025.
#  Top K precision = 0.09468267581475155, recall = 0.007152331599755644.
# Training on epoch 2 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.694077, and regularization loss is 0.00093.
#  Top K precision = 0.08844133099824897, recall = 0.006808403692513166.
# Training on epoch 2 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.694, and regularization loss is 0.000853.
#  Top K precision = 0.08917975567190255, recall = 0.006815356703470894.
#
# Training on 2 epoch completed.
#  Average bpr_loss on train set is 0.000686 for the current epoch.
#  Training top K precision = 0.04612500000000014, recall = 0.0036661121746852095.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.03350000000000006, recall = 0.0026072440133214927.
#
# Training on the 3 epoch
# Training on epoch 3 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693918, and regularization loss is 0.000771.
#  Top K precision = 0.09442508710801426, recall = 0.006836605906705136.
# Training on epoch 3 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693839, and regularization loss is 0.000692.
#  Top K precision = 0.08925476603119607, recall = 0.00697363573473552.
# Training on epoch 3 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693799, and regularization loss is 0.000652.
#  Top K precision = 0.08665511265164666, recall = 0.006760284754530274.
# Training on epoch 3 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693739, and regularization loss is 0.000591.
#  Top K precision = 0.09171075837742529, recall = 0.007098404504037117.
# Training on epoch 3 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693694, and regularization loss is 0.000547.
#  Top K precision = 0.087346221441125, recall = 0.0071158907344673426.
# Training on epoch 3 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693642, and regularization loss is 0.000494.
#  Top K precision = 0.09217391304347858, recall = 0.007152704896950333.
# Training on epoch 3 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693611, and regularization loss is 0.000464.
#  Top K precision = 0.09020979020979052, recall = 0.006793155787042754.
# Training on epoch 3 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693576, and regularization loss is 0.000429.
#  Top K precision = 0.08867595818815366, recall = 0.007272176808826455.
#
# Training on 3 epoch completed.
#  Average bpr_loss on train set is 0.000685 for the current epoch.
#  Training top K precision = 0.04812500000000014, recall = 0.0036823127502808163.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.032750000000000064, recall = 0.002646825049329742.
#
# Training on the 4 epoch
# Training on epoch 4 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693528, and regularization loss is 0.000381.
#  Top K precision = 0.08948275862068995, recall = 0.007176247760701592.
# Training on epoch 4 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693502, and regularization loss is 0.000355.
#  Top K precision = 0.08573883161512051, recall = 0.006697239289568707.
# Training on epoch 4 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.69346, and regularization loss is 0.000312.
#  Top K precision = 0.08670212765957469, recall = 0.006546691330558243.
# Training on epoch 4 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693445, and regularization loss is 0.000297.
#  Top K precision = 0.09130434782608726, recall = 0.006923261445426718.
# Training on epoch 4 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693424, and regularization loss is 0.000276.
#  Top K precision = 0.08717504332755657, recall = 0.0066434874855583435.
# Training on epoch 4 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693408, and regularization loss is 0.000261.
#  Top K precision = 0.09296740994854238, recall = 0.007395066951127236.
# Training on epoch 4 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693389, and regularization loss is 0.000242.
#  Top K precision = 0.0879725085910656, recall = 0.006752534192206899.
# Training on epoch 4 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693364, and regularization loss is 0.000217.
#  Top K precision = 0.08368055555555587, recall = 0.006306398214681783.
#
# Training on 4 epoch completed.
#  Average bpr_loss on train set is 0.000685 for the current epoch.
#  Training top K precision = 0.04812500000000014, recall = 0.003876588118128256.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.032250000000000056, recall = 0.002503479763338638.
#
# Training on the 5 epoch
# Training on epoch 5 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693365, and regularization loss is 0.000217.
#  Top K precision = 0.08845500848896462, recall = 0.007134815127798019.
# Training on epoch 5 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693332, and regularization loss is 0.000185.
#  Top K precision = 0.08690476190476222, recall = 0.006916556175522597.
# Training on epoch 5 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693338, and regularization loss is 0.00019.
#  Top K precision = 0.08704663212435255, recall = 0.00648878559790472.
# Training on epoch 5 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.69331, and regularization loss is 0.000163.
#  Top K precision = 0.09045996592844996, recall = 0.0070636311373835315.
# Training on epoch 5 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693301, and regularization loss is 0.000154.
#  Top K precision = 0.08890784982935175, recall = 0.006871935302273562.
# Training on epoch 5 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693302, and regularization loss is 0.000154.
#  Top K precision = 0.09274611398963759, recall = 0.007193707786212001.
# Training on epoch 5 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693279, and regularization loss is 0.000131.
#  Top K precision = 0.08906810035842318, recall = 0.006893331195146165.
# Training on epoch 5 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693273, and regularization loss is 0.000126.
#  Top K precision = 0.08630136986301389, recall = 0.006589422465984721.
#
# Training on 5 epoch completed.
#  Average bpr_loss on train set is 0.000685 for the current epoch.
#  Training top K precision = 0.04912500000000014, recall = 0.00403828389965386.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.033250000000000064, recall = 0.002407262948343182.
#
# Training on the 6 epoch
# Training on epoch 6 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693269, and regularization loss is 0.000121.
#  Top K precision = 0.09100346020761281, recall = 0.007193415990443293.
# Training on epoch 6 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693259, and regularization loss is 0.000111.
#  Top K precision = 0.08882978723404279, recall = 0.007119946988215847.
# Training on epoch 6 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693253, and regularization loss is 0.000105.
#  Top K precision = 0.09064124783362242, recall = 0.007054503305708756.
# Training on epoch 6 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.69324, and regularization loss is 9.2e-05.
#  Top K precision = 0.08537414965986426, recall = 0.007065283906187661.
# Training on epoch 6 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693235, and regularization loss is 8.7e-05.
#  Top K precision = 0.08601769911504446, recall = 0.0066470824452401255.
# Training on epoch 6 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.69324, and regularization loss is 9.2e-05.
#  Top K precision = 0.08896434634974561, recall = 0.006835598338541058.
# Training on epoch 6 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693219, and regularization loss is 7.2e-05.
#  Top K precision = 0.08711340206185594, recall = 0.006343393859378338.
# Training on epoch 6 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693226, and regularization loss is 7.9e-05.
#  Top K precision = 0.08336192109777037, recall = 0.006616148581201818.
#
# Training on 6 epoch completed.
#  Average bpr_loss on train set is 0.000685 for the current epoch.
#  Training top K precision = 0.052750000000000206, recall = 0.004377766969971979.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.03775000000000007, recall = 0.0030623736680889507.
#
# Training on the 7 epoch
# Training on epoch 7 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693227, and regularization loss is 7.9e-05.
#  Top K precision = 0.08902027027027057, recall = 0.0068825051918974586.
# Training on epoch 7 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.69322, and regularization loss is 7.3e-05.
#  Top K precision = 0.08877551020408184, recall = 0.006694170965937112.
# Training on epoch 7 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693217, and regularization loss is 7e-05.
#  Top K precision = 0.09051724137931057, recall = 0.007278694385368776.
# Training on epoch 7 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693209, and regularization loss is 6.2e-05.
#  Top K precision = 0.08986254295532674, recall = 0.006915113710102805.
# Training on epoch 7 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693203, and regularization loss is 5.6e-05.
#  Top K precision = 0.08810344827586229, recall = 0.006814540628829286.
# Training on epoch 7 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693209, and regularization loss is 6.1e-05.
#  Top K precision = 0.08856624319419262, recall = 0.006857695651329861.
# Training on epoch 7 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693207, and regularization loss is 5.9e-05.
#  Top K precision = 0.08726003490401421, recall = 0.006578701037901415.
# Training on epoch 7 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693194, and regularization loss is 4.6e-05.
#  Top K precision = 0.08946488294314407, recall = 0.006962148720838801.
#
# Training on 7 epoch completed.
#  Average bpr_loss on train set is 0.000685 for the current epoch.
#  Training top K precision = 0.06125000000000025, recall = 0.004979644942529593.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.05125000000000016, recall = 0.0047217682596107854.
#
# Training on the 8 epoch
# Training on epoch 8 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693194, and regularization loss is 4.7e-05.
#  Top K precision = 0.085542168674699, recall = 0.006368534478222534.
# Training on epoch 8 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693196, and regularization loss is 4.8e-05.
#  Top K precision = 0.08810344827586233, recall = 0.007013414244571812.
# Training on epoch 8 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693195, and regularization loss is 4.8e-05.
#  Top K precision = 0.08811544991511068, recall = 0.007012293646972384.
# Training on epoch 8 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693192, and regularization loss is 4.5e-05.
#  Top K precision = 0.08102836879432655, recall = 0.006669724947028585.
# Training on epoch 8 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693185, and regularization loss is 3.8e-05.
#  Top K precision = 0.08883248730964492, recall = 0.006782907044221661.
# Training on epoch 8 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693179, and regularization loss is 3.2e-05.
#  Top K precision = 0.08974358974359004, recall = 0.006921077794963601.
# Training on epoch 8 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693188, and regularization loss is 4.1e-05.
#  Top K precision = 0.08900169204737766, recall = 0.006660071500221305.
# Training on epoch 8 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693185, and regularization loss is 3.8e-05.
#  Top K precision = 0.09049235993208857, recall = 0.007147083413209589.
#
# Training on 8 epoch completed.
#  Average bpr_loss on train set is 0.000685 for the current epoch.
#  Training top K precision = 0.06900000000000026, recall = 0.005453434652471829.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.06250000000000024, recall = 0.005261741086490318.
#
# Training on the 9 epoch
# Training on epoch 9 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693186, and regularization loss is 3.9e-05.
#  Top K precision = 0.08379310344827605, recall = 0.006586467658464104.
# Training on epoch 9 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693178, and regularization loss is 3.1e-05.
#  Top K precision = 0.08773747841105378, recall = 0.006469966791654902.
# Training on epoch 9 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693175, and regularization loss is 2.8e-05.
#  Top K precision = 0.08950086058519816, recall = 0.006893025294626702.
# Training on epoch 9 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693174, and regularization loss is 2.6e-05.
#  Top K precision = 0.08921739130434812, recall = 0.0068941143053166684.
# Training on epoch 9 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693173, and regularization loss is 2.6e-05.
#  Top K precision = 0.08595600676818982, recall = 0.006643983018219031.
# Training on epoch 9 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693179, and regularization loss is 3.2e-05.
#  Top K precision = 0.09058614564831281, recall = 0.006781676609061548.
# Training on epoch 9 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693179, and regularization loss is 3.1e-05.
#  Top K precision = 0.08881239242685057, recall = 0.0067600159073638215.
# Training on epoch 9 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693171, and regularization loss is 2.3e-05.
#  Top K precision = 0.0902826855123678, recall = 0.007026440152751927.
#
# Training on 9 epoch completed.
#  Average bpr_loss on train set is 0.000685 for the current epoch.
#  Training top K precision = 0.07637500000000029, recall = 0.00614491577087534.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.07087500000000026, recall = 0.005742624533953438.
#
# Training on the 10 epoch
# Training on epoch 10 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693173, and regularization loss is 2.5e-05.
#  Top K precision = 0.08784246575342483, recall = 0.0068366482052381146.
# Training on epoch 10 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693173, and regularization loss is 2.5e-05.
#  Top K precision = 0.08450000000000021, recall = 0.006676511505791513.
# Training on epoch 10 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693168, and regularization loss is 2e-05.
#  Top K precision = 0.09049295774647913, recall = 0.006985767092764074.
# Training on epoch 10 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693163, and regularization loss is 1.6e-05.
#  Top K precision = 0.08773747841105378, recall = 0.0070391314046203395.
# Training on epoch 10 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693173, and regularization loss is 2.6e-05.
#  Top K precision = 0.08628762541806048, recall = 0.0067680310051424705.
# Training on epoch 10 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693169, and regularization loss is 2.2e-05.
#  Top K precision = 0.08828671328671349, recall = 0.006654987534533275.
# Training on epoch 10 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693169, and regularization loss is 2.1e-05.
#  Top K precision = 0.09154929577464814, recall = 0.006695912055726596.
# Training on epoch 10 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693166, and regularization loss is 1.8e-05.
#  Top K precision = 0.09111498257839744, recall = 0.006785496623563493.
#
# Training on 10 epoch completed.
#  Average bpr_loss on train set is 0.000685 for the current epoch.
#  Training top K precision = 0.07887500000000026, recall = 0.006040335082782482.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08062500000000034, recall = 0.006300829853565556.
#
# Training on the 11 epoch
# Training on epoch 11 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693165, and regularization loss is 1.8e-05.
#  Top K precision = 0.08438596491228097, recall = 0.006292622024004469.
# Training on epoch 11 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.69317, and regularization loss is 2.2e-05.
#  Top K precision = 0.08844827586206916, recall = 0.006811702765518294.
# Training on epoch 11 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693159, and regularization loss is 1.2e-05.
#  Top K precision = 0.08914590747330983, recall = 0.00706635078681128.
# Training on epoch 11 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693165, and regularization loss is 1.8e-05.
#  Top K precision = 0.09011925042589462, recall = 0.006773356700992398.
# Training on epoch 11 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693161, and regularization loss is 1.3e-05.
#  Top K precision = 0.0916955017301041, recall = 0.007296706037038544.
# Training on epoch 11 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693164, and regularization loss is 1.7e-05.
#  Top K precision = 0.08881355932203414, recall = 0.0068646318875791815.
# Training on epoch 11 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693161, and regularization loss is 1.3e-05.
#  Top K precision = 0.09291736930860059, recall = 0.006797085735505319.
# Training on epoch 11 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693161, and regularization loss is 1.4e-05.
#  Top K precision = 0.08848920863309374, recall = 0.00679834788062156.
#
# Training on 11 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.0860000000000003, recall = 0.006673282081008233.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.0838750000000003, recall = 0.006583301199881309.
#
# Training on the 12 epoch
# Training on epoch 12 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693165, and regularization loss is 1.7e-05.
#  Top K precision = 0.08961937716263005, recall = 0.006988323065683071.
# Training on epoch 12 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693162, and regularization loss is 1.4e-05.
#  Top K precision = 0.08668941979522209, recall = 0.006494249017784965.
# Training on epoch 12 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693159, and regularization loss is 1.2e-05.
#  Top K precision = 0.08915662650602434, recall = 0.0069273060810192705.
# Training on epoch 12 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693159, and regularization loss is 1.2e-05.
#  Top K precision = 0.08734835355285984, recall = 0.006681786324002904.
# Training on epoch 12 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.69316, and regularization loss is 1.2e-05.
#  Top K precision = 0.08851590106007096, recall = 0.006484334005834765.
# Training on epoch 12 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.69316, and regularization loss is 1.3e-05.
#  Top K precision = 0.0919795221843006, recall = 0.007057071273084907.
# Training on epoch 12 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693162, and regularization loss is 1.5e-05.
#  Top K precision = 0.08797909407665523, recall = 0.006572022235269202.
# Training on epoch 12 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693157, and regularization loss is 1e-05.
#  Top K precision = 0.08644067796610194, recall = 0.006804102397946395.
#
# Training on 12 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08750000000000005, recall = 0.0068073924985784925.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08687500000000024, recall = 0.0067075329233419675.
#
# Training on the 13 epoch
# Training on epoch 13 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693159, and regularization loss is 1.1e-05.
#  Top K precision = 0.08503521126760587, recall = 0.006794168106324339.
# Training on epoch 13 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693156, and regularization loss is 9e-06.
#  Top K precision = 0.08941979522184325, recall = 0.007120703552862717.
# Training on epoch 13 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.69316, and regularization loss is 1.2e-05.
#  Top K precision = 0.09269102990033251, recall = 0.007343616554074816.
# Training on epoch 13 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693155, and regularization loss is 8e-06.
#  Top K precision = 0.08675721561969471, recall = 0.006682778289358702.
# Training on epoch 13 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693158, and regularization loss is 1.1e-05.
#  Top K precision = 0.08419243986254327, recall = 0.006624280327933988.
# Training on epoch 13 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693157, and regularization loss is 9e-06.
#  Top K precision = 0.08726333907056825, recall = 0.006772313372631604.
# Training on epoch 13 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693159, and regularization loss is 1.1e-05.
#  Top K precision = 0.08512110726643624, recall = 0.0065416502827119125.
# Training on epoch 13 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693159, and regularization loss is 1.2e-05.
#  Top K precision = 0.08613518197573684, recall = 0.006804249828853143.
#
# Training on 13 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08725000000000022, recall = 0.006725695170977095.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08825000000000026, recall = 0.006822947902397506.
#
# Training on the 14 epoch
# Training on epoch 14 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693156, and regularization loss is 8e-06.
#  Top K precision = 0.08970331588132661, recall = 0.007067427783852711.
# Training on epoch 14 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.69316, and regularization loss is 1.2e-05.
#  Top K precision = 0.08966725043782861, recall = 0.00693581649996766.
# Training on epoch 14 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693157, and regularization loss is 1e-05.
#  Top K precision = 0.09485815602836906, recall = 0.007134140376446749.
# Training on epoch 14 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693158, and regularization loss is 1e-05.
#  Top K precision = 0.08663194444444466, recall = 0.006677993099175465.
# Training on epoch 14 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 5e-06.
#  Top K precision = 0.08818493150684954, recall = 0.006448310002808873.
# Training on epoch 14 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693154, and regularization loss is 6e-06.
#  Top K precision = 0.09092495636998274, recall = 0.006726759229295401.
# Training on epoch 14 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693154, and regularization loss is 7e-06.
#  Top K precision = 0.08241379310344857, recall = 0.006852929081763654.
# Training on epoch 14 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693156, and regularization loss is 8e-06.
#  Top K precision = 0.08786324786324813, recall = 0.006964786823862979.
#
# Training on 14 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08837500000000015, recall = 0.0067907790250695335.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 15 epoch
# Training on epoch 15 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 4e-06.
#  Top K precision = 0.08640275387263363, recall = 0.006373635803788353.
# Training on epoch 15 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693154, and regularization loss is 6e-06.
#  Top K precision = 0.09060402684563788, recall = 0.0066417897210979265.
# Training on epoch 15 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693155, and regularization loss is 8e-06.
#  Top K precision = 0.08940972222222253, recall = 0.0074289896774886975.
# Training on epoch 15 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693153, and regularization loss is 6e-06.
#  Top K precision = 0.0905594405594408, recall = 0.00713798456319298.
# Training on epoch 15 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 5e-06.
#  Top K precision = 0.09122203098106739, recall = 0.007186700761462829.
# Training on epoch 15 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693153, and regularization loss is 6e-06.
#  Top K precision = 0.08707964601769932, recall = 0.006660561147250319.
# Training on epoch 15 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693155, and regularization loss is 8e-06.
#  Top K precision = 0.09068965517241405, recall = 0.007418610733942758.
# Training on epoch 15 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693156, and regularization loss is 9e-06.
#  Top K precision = 0.0885135135135138, recall = 0.007144565163455971.
#
# Training on 15 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000012, recall = 0.006849333317998824.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 16 epoch
# Training on epoch 16 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693153, and regularization loss is 5e-06.
#  Top K precision = 0.08663194444444475, recall = 0.006965039480918454.
# Training on epoch 16 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693154, and regularization loss is 6e-06.
#  Top K precision = 0.08800705467372161, recall = 0.0065710738989790875.
# Training on epoch 16 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693157, and regularization loss is 9e-06.
#  Top K precision = 0.09031141868512133, recall = 0.006716436862508288.
# Training on epoch 16 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693154, and regularization loss is 6e-06.
#  Top K precision = 0.08900523560209447, recall = 0.006761151480049382.
# Training on epoch 16 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 4e-06.
#  Top K precision = 0.08842832469775498, recall = 0.00681290007121833.
# Training on epoch 16 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 4e-06.
#  Top K precision = 0.09225473321858893, recall = 0.006907938005208764.
# Training on epoch 16 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693153, and regularization loss is 5e-06.
#  Top K precision = 0.08807495741056251, recall = 0.006768792724748043.
# Training on epoch 16 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 4e-06.
#  Top K precision = 0.0880208333333336, recall = 0.006823553446285761.
#
# Training on 16 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08850000000000012, recall = 0.006846269592508622.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 17 epoch
# Training on epoch 17 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 5e-06.
#  Top K precision = 0.08766891891891915, recall = 0.006852166624283591.
# Training on epoch 17 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 5e-06.
#  Top K precision = 0.08812056737588678, recall = 0.006553243594718124.
# Training on epoch 17 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 4e-06.
#  Top K precision = 0.09139784946236583, recall = 0.006697267145229561.
# Training on epoch 17 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 5e-06.
#  Top K precision = 0.08863636363636392, recall = 0.006989743991974301.
# Training on epoch 17 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 4e-06.
#  Top K precision = 0.08632326820603925, recall = 0.006266186206572913.
# Training on epoch 17 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693153, and regularization loss is 6e-06.
#  Top K precision = 0.09371816638370141, recall = 0.0072899335018065566.
# Training on epoch 17 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 5e-06.
#  Top K precision = 0.08291814946619233, recall = 0.007012287144856292.
# Training on epoch 17 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 3e-06.
#  Top K precision = 0.08855633802816935, recall = 0.006559615843850204.
#
# Training on 17 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08850000000000016, recall = 0.00684412498466549.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 18 epoch
# Training on epoch 18 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693153, and regularization loss is 5e-06.
#  Top K precision = 0.09268292682926858, recall = 0.007061609969500402.
# Training on epoch 18 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 3e-06.
#  Top K precision = 0.08846815834767667, recall = 0.006961052130649277.
# Training on epoch 18 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 4e-06.
#  Top K precision = 0.09485420240137248, recall = 0.006832475633267196.
# Training on epoch 18 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693152, and regularization loss is 5e-06.
#  Top K precision = 0.09214659685863905, recall = 0.006882706068884949.
# Training on epoch 18 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693153, and regularization loss is 6e-06.
#  Top K precision = 0.08625429553264632, recall = 0.006659366809756991.
# Training on epoch 18 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 3e-06.
#  Top K precision = 0.08711340206185599, recall = 0.006985101584463634.
# Training on epoch 18 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 3e-06.
#  Top K precision = 0.0964539007092201, recall = 0.007131987260032339.
# Training on epoch 18 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 4e-06.
#  Top K precision = 0.08559027777777806, recall = 0.006651944888925915.
#
# Training on 18 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000008, recall = 0.006849333317998816.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 19 epoch
# Training on epoch 19 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 3e-06.
#  Top K precision = 0.08801369863013722, recall = 0.006904599826871654.
# Training on epoch 19 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.0910806174957121, recall = 0.007195637459280887.
# Training on epoch 19 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 2e-06.
#  Top K precision = 0.08913412563667258, recall = 0.0071178351449641825.
# Training on epoch 19 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 3e-06.
#  Top K precision = 0.0880829015544044, recall = 0.0069277756238729235.
# Training on epoch 19 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 3e-06.
#  Top K precision = 0.09111498257839748, recall = 0.0071584232933892735.
# Training on epoch 19 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 2e-06.
#  Top K precision = 0.08388791593695297, recall = 0.006794461364934898.
# Training on epoch 19 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 2e-06.
#  Top K precision = 0.09232142857142878, recall = 0.007126482050643558.
# Training on epoch 19 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 2e-06.
#  Top K precision = 0.08987993138936563, recall = 0.006621976179612899.
#
# Training on 19 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000015, recall = 0.0068493333179988234.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 20 epoch
# Training on epoch 20 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 2e-06.
#  Top K precision = 0.08423817863397573, recall = 0.006805875991873196.
# Training on epoch 20 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 3e-06.
#  Top K precision = 0.08802698145025319, recall = 0.00663257031471195.
# Training on epoch 20 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 2e-06.
#  Top K precision = 0.08730434782608722, recall = 0.006856162502725727.
# Training on epoch 20 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 2e-06.
#  Top K precision = 0.08486394557823157, recall = 0.006760293852594735.
# Training on epoch 20 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 2e-06.
#  Top K precision = 0.08873949579831965, recall = 0.006933826329890588.
# Training on epoch 20 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 2e-06.
#  Top K precision = 0.09035087719298265, recall = 0.006658731351576821.
# Training on epoch 20 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693151, and regularization loss is 3e-06.
#  Top K precision = 0.08727915194346317, recall = 0.006682347073100352.
# Training on epoch 20 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 2e-06.
#  Top K precision = 0.087074829931973, recall = 0.006790323151064709.
#
# Training on 20 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000027, recall = 0.006849333317998815.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 21 epoch
# Training on epoch 21 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 2e-06.
#  Top K precision = 0.09006849315068523, recall = 0.006679535087660265.
# Training on epoch 21 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 2e-06.
#  Top K precision = 0.09016949152542394, recall = 0.006897506469286156.
# Training on epoch 21 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 3e-06.
#  Top K precision = 0.08873949579831955, recall = 0.006481673428660058.
# Training on epoch 21 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 3e-06.
#  Top K precision = 0.09207419898819587, recall = 0.006845813898666539.
# Training on epoch 21 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 2e-06.
#  Top K precision = 0.09182608695652199, recall = 0.006772240572521782.
# Training on epoch 21 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.0847222222222225, recall = 0.006641613342850714.
# Training on epoch 21 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 2e-06.
#  Top K precision = 0.08910369068541325, recall = 0.007205831943487437.
# Training on epoch 21 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.08915662650602434, recall = 0.006890081535224599.
#
# Training on 21 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000019, recall = 0.00684933331799882.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 22 epoch
# Training on epoch 22 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.08491525423728831, recall = 0.006567102313894127.
# Training on epoch 22 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.0866666666666669, recall = 0.006881000532285222.
# Training on epoch 22 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.08750000000000024, recall = 0.00707546445392326.
# Training on epoch 22 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.0923478260869568, recall = 0.006910363326675324.
# Training on epoch 22 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.08573975044563305, recall = 0.006861178938218276.
# Training on epoch 22 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.08668941979522209, recall = 0.00684601297198169.
# Training on epoch 22 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.69315, and regularization loss is 2e-06.
#  Top K precision = 0.09051724137931061, recall = 0.006778923684002989.
# Training on epoch 22 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.08902654867256653, recall = 0.006861725622795737.
#
# Training on 22 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000013, recall = 0.006849333317998817.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 23 epoch
# Training on epoch 23 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 2e-06.
#  Top K precision = 0.08975694444444461, recall = 0.006775675071424026.
# Training on epoch 23 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.08792517006802748, recall = 0.00686734741129866.
# Training on epoch 23 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.08480138169257363, recall = 0.006407484725538.
# Training on epoch 23 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.08888888888888917, recall = 0.006796719491455871.
# Training on epoch 23 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.09095563139931767, recall = 0.006822241075939958.
# Training on epoch 23 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.08625429553264634, recall = 0.006626754122487225.
# Training on epoch 23 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.08838821490467967, recall = 0.006857095546570612.
# Training on epoch 23 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.08452173913043504, recall = 0.006876007392126685.
#
# Training on 23 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000016, recall = 0.006849333317998817.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 24 epoch
# Training on epoch 24 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693149, and regularization loss is 1e-06.
#  Top K precision = 0.0918965517241382, recall = 0.007073617618596797.
# Training on epoch 24 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.08850771869639829, recall = 0.0071073833491063065.
# Training on epoch 24 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693148, and regularization loss is 1e-06.
#  Top K precision = 0.0912671232876714, recall = 0.0067052302329846224.
# Training on epoch 24 minibatch 31/79 completed
# ...
#  Top K precision = 0.08966725043782862, recall = 0.0068570609653282695.
# Training on epoch 61 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08614035087719324, recall = 0.006873769859021483.
#
# Training on 61 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000004, recall = 0.006849333317998822.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 62 epoch
# Training on epoch 62 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08425460636515941, recall = 0.00638264544649382.
# Training on epoch 62 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08653846153846173, recall = 0.006827025329593532.
# Training on epoch 62 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09028960817717231, recall = 0.006702586318089371.
# Training on epoch 62 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08774080560420341, recall = 0.0068086916333158585.
# Training on epoch 62 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08595600676818974, recall = 0.006706636197486956.
# Training on epoch 62 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08439716312056758, recall = 0.006875672040274897.
# Training on epoch 62 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08961267605633827, recall = 0.006921618177259912.
# Training on epoch 62 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0874363327674026, recall = 0.006812493830610771.
#
# Training on 62 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000013, recall = 0.00684933331799882.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 63 epoch
# Training on epoch 63 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08955479452054818, recall = 0.006975254867841611.
# Training on epoch 63 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08664383561643864, recall = 0.006785497253422416.
# Training on epoch 63 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08687392055267724, recall = 0.0067974153137117955.
# Training on epoch 63 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09086115992970151, recall = 0.006875078693068828.
# Training on epoch 63 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08955479452054822, recall = 0.00721634610268881.
# Training on epoch 63 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09003496503496528, recall = 0.007052337741369982.
# Training on epoch 63 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09399656946826788, recall = 0.0071596228055949155.
# Training on epoch 63 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0882758620689658, recall = 0.007115062634544713.
#
# Training on 63 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000013, recall = 0.006849333317998815.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 64 epoch
# Training on epoch 64 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09169550173010411, recall = 0.006910734174051563.
# Training on epoch 64 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0866900175131351, recall = 0.006669944341569722.
# Training on epoch 64 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08989547038327547, recall = 0.006545103629264874.
# Training on epoch 64 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08764805414551635, recall = 0.006796808611540649.
# Training on epoch 64 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0865008880994674, recall = 0.007028514980148632.
# Training on epoch 64 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0870337477797516, recall = 0.006866925075070977.
# Training on epoch 64 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08674496644295335, recall = 0.006699818957316021.
# Training on epoch 64 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08640275387263362, recall = 0.006563311320132277.
#
# Training on 64 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000013, recall = 0.006849333317998823.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 65 epoch
# Training on epoch 65 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08910034602076156, recall = 0.006913263018651085.
# Training on epoch 65 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.088428324697755, recall = 0.007084569343115644.
# Training on epoch 65 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08528896672504402, recall = 0.0064890132036662185.
# Training on epoch 65 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.085714285714286, recall = 0.0070242651207069245.
# Training on epoch 65 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08706896551724164, recall = 0.00725448589810435.
# Training on epoch 65 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08890756302521037, recall = 0.007049358129820987.
# Training on epoch 65 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08608695652173937, recall = 0.0063640886375277836.
# Training on epoch 65 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09175438596491256, recall = 0.007312054326351703.
#
# Training on 65 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000009, recall = 0.006849333317998827.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 66 epoch
# Training on epoch 66 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08873720136518796, recall = 0.00712157815904303.
# Training on epoch 66 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0879251700680274, recall = 0.00675957440984677.
# Training on epoch 66 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09147826086956552, recall = 0.0070961691148017795.
# Training on epoch 66 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0858885017421605, recall = 0.00692928969023959.
# Training on epoch 66 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0928934010152287, recall = 0.007127054958537362.
# Training on epoch 66 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08955479452054821, recall = 0.006893026075010107.
# Training on epoch 66 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09029462738301582, recall = 0.006989870510273119.
# Training on epoch 66 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09230769230769259, recall = 0.007049981720489582.
#
# Training on 66 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.0886250000000002, recall = 0.006849333317998826.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 67 epoch
# Training on epoch 67 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09108061749571215, recall = 0.006964828832238744.
# Training on epoch 67 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08681898066783858, recall = 0.006601869614621393.
# Training on epoch 67 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08779661016949179, recall = 0.006390553319526577.
# Training on epoch 67 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08640275387263362, recall = 0.007263153216403866.
# Training on epoch 67 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08612521150592248, recall = 0.006945101193295192.
# Training on epoch 67 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09114583333333359, recall = 0.007070034865768617.
# Training on epoch 67 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08845500848896466, recall = 0.0070683951041504356.
# Training on epoch 67 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0904513888888891, recall = 0.0069221114088471826.
#
# Training on 67 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000013, recall = 0.0068493333179988234.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 68 epoch
# Training on epoch 68 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08581436077057818, recall = 0.006682197159960019.
# Training on epoch 68 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0859375000000003, recall = 0.006333592015377448.
# Training on epoch 68 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0927461139896376, recall = 0.007242799781699154.
# Training on epoch 68 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08541666666666686, recall = 0.006720983337007207.
# Training on epoch 68 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08419182948490252, recall = 0.006806557060710946.
# Training on epoch 68 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08406304728546429, recall = 0.006768218880780541.
# Training on epoch 68 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08648180242634339, recall = 0.006710216611637051.
# Training on epoch 68 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08986013986014009, recall = 0.00655328877321554.
#
# Training on 68 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000019, recall = 0.006849333317998827.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.
#
# Training on the 69 epoch
# Training on epoch 69 minibatch 1/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09058614564831292, recall = 0.006635424937717469.
# Training on epoch 69 minibatch 11/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.0957066189624332, recall = 0.007567242040142077.
# Training on epoch 69 minibatch 21/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09122203098106733, recall = 0.006853201127787982.
# Training on epoch 69 minibatch 31/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09166666666666702, recall = 0.006939377374105966.
# Training on epoch 69 minibatch 41/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08752107925801034, recall = 0.006755670302123325.
# Training on epoch 69 minibatch 51/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08564189189189206, recall = 0.006668747066276159.
# Training on epoch 69 minibatch 61/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.09420783645655903, recall = 0.007127756070350978.
# Training on epoch 69 minibatch 71/79 completed
#  bpr_loss on current minibatch is 0.693147, and regularization loss is 0.0.
#  Top K precision = 0.08691099476439816, recall = 0.006607156266554909.
#
# Training on 69 epoch completed.
#  Average bpr_loss on train set is 0.000684 for the current epoch.
#  Training top K precision = 0.08862500000000006, recall = 0.0068493333179988234.
#  Average bpr_loss on the validation set is 9e-06, and regularization loss is 0.0.
#  Validation top K precision = 0.08862500000000023, recall = 0.006849333317998818.

# %% [markdown]
# ### Plot top K precision over epochs

# %%
plt.plot(epochs_tracked, [precision for precision, _ in train_topks],
         label="Train")
plt.plot(epochs_tracked, [precision for precision, _ in val_topks],
         label="Val")
plt.ylabel(f"Top {K} precision")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ### Plot top K recall over epochs

# %%
plt.plot(epochs_tracked, [recall for _, recall in train_topks],
         label="Train")
plt.plot(epochs_tracked, [recall for _, recall in val_topks],
         label="Val")
plt.ylabel(f"Top {K} recall")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## Test
#
# After training, let's test our model on the test set.

# %%
# predict on the test set
lightGCN.eval()
print("Training completed after {} epochs".format(epochs))

users_test = samples_test[:, 0:1]
pos_test = samples_test[:, 1:2]
neg_test = samples_test[:, 2:3]

loss_test, reg_loss_test = bpr_loss(
    lightGCN, users_test, pos_test, neg_test, data, test_mask)
reg_loss_test = reg_loss_test * weight_decay

# predict on the test set
user_indices = samples_test[:, 0]
user_indices = user_indices.repeat(2).long()
item_indices = torch.cat((samples_test[:, 1], samples_test[:, 2])).long()
pred_test = getUsersRating(lightGCN, users_test[:,0], data)\
    [user_indices, item_indices]
truth_test = data["edge_index"][users_test.long()[:,0]]\
    [user_indices, item_indices]
test_topk_precision, test_topk_recall = personalized_topk(
    pred_test, K, user_indices, data["edge_index"])

print("Average bpr_loss on the test set is {}, and regularization loss is {}.\n".format(round(float((loss_test+reg_loss_test)/len(samples_test)), 6),
                                                                                                round(float(reg_loss_test/len(samples_test)), 6)),
      "Top K precision = {}, recall = {}.".format(test_topk_precision, test_topk_recall))

# Save model embeddings.
torch.save(lightGCN, config_dict["model_name"])
# Out:
# Training completed after 70 epochs
# tensor([0.5000, 0.5000, 0.5000,  ..., 0.5000, 0.5000, 0.5000], device='cuda:0',
#        grad_fn=<IndexBackward0>)
# Average bpr_loss on the test set is 9e-06, and regularization loss is 0.0.
#  Top K precision = 0.08862500000000023, recall = 0.006849333317998818.

# %% [markdown]
# # Run matrix factorization as baseline performance
#
# As a baseline, we can run [PARAFAC matrix factorization](https://www.sciencedirect.com/science/article/abs/pii/S0169743997000324) on the dataset. We use the [TensorLy](http://tensorly.org/dev/modules/generated/tensorly.decomposition.parafac.html#tensorly.decomposition.parafac) library.

# %%
def matrix_factorization(user_item, rank):
    """Runs matrix factorization on `user_item` and get user-item similarities.

    Args:
        user_item: User-item connectivity matrix.
        rank: Number of numbers to represent a user / item.

    Returns:
        User-item similarities.
    """
    weights, (user_factors, item_factors) = \
        decomposition.parafac(user_item, rank)
    similarities = user_factors @ item_factors.T
    return 1 / (1 + np.exp(- similarities))

# %% [markdown]
# We observe that our LightGCN model delivers betters performance than matrix factorization.

# %%
# Compute baseline metrics using matrix factorization.
baseline_pred = matrix_factorization(
        data["edge_index"].detach().cpu().numpy(),
        config_dict["mf_rank"])[user_indices.cpu(), item_indices.cpu()]
baseline_topk_precision, baseline_topk_recall = \
        personalized_topk(baseline_pred, K, user_indices, data["edge_index"])
print("Baseline (PARAFAC matrix factorization) produces ",
      "Top K precision = {}, recall = {}.".format(baseline_topk_precision,
                                                  baseline_topk_recall))
# Out:
# Baseline (PARAFAC matrix factorization) produces  Top K precision = 0.04612500000000016, recall = 0.003719243696892312.
